# %% [markdown]
# # 자동차 연비 회귀모델
# - Auto MPG 데이터셋을 사용하여 1970년대 후반과 1980년대 초반의 자동차 연비를 예측하는 모델을 만듭니다.
# - 이 정보에는 실린더 수, 배기량, 마력(horsepower), 공차 중량 같은 속성이 포함됩니다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 구글 드라이브 마운트
# from google.colab import drive
# drive.mount('/content/drive')

# Working Directory 설정
# import os
# os.chdir('/content/drive/MyDrive/data')

# %% [markdown]
# 파일은 auto-mpg.csv 입니다.

# %%
df = pd.read_csv('./datas_dnn/auto-mpg.csv')

# %%
df.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr  origin                       name
# 0  18.0    8  307.0  130    3504   12.0  70       1  chevrolet chevelle malibu
# 1  15.0    8  350.0  165    3693   11.5  70       1          buick skylark 320
# 2  18.0    8  318.0  150    3436   11.0  70       1         plymouth satellite
# 3  16.0    8  304.0  150    3433   12.0  70       1              amc rebel sst
# 4  17.0    8  302.0  140    3449   10.5  70       1                ford torino

# %%
df.isna().sum()
# Out:
# mpg       0
# cyl       0
# displ     0
# hp        0
# weight    0
# accel     0
# yr        0
# origin    0
# name      0
# dtype: int64

# %%
y = df['mpg']

# %%
X = df.loc[ : ,'cyl' : 'origin' ]

# %%
X.head(2)
# Out:
#    cyl  displ   hp  weight  accel  yr  origin
# 0    8  307.0  130    3504   12.0  70       1
# 1    8  350.0  165    3693   11.5  70       1

# %%
y.head()
# Out:
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# Name: mpg, dtype: float64

# %% [markdown]
# # 데이터 준비

# %% [markdown]
# ## 데이터 정규화

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %% [markdown]
# ### X 데이터 정규화

# %%
# X데이터 정규화 객체
sc_X = MinMaxScaler()

# %%
X_scaled = sc_X.fit_transform(X)
X_scaled[:5]
# Out:
# array([[1.        , 0.61757106, 0.45652174, 0.5361497 , 0.23809524,
#         0.        , 0.        ],
#        [1.        , 0.72868217, 0.64673913, 0.58973632, 0.20833333,
#         0.        , 0.        ],
#        [1.        , 0.64599483, 0.56521739, 0.51686986, 0.17857143,
#         0.        , 0.        ],
#        [1.        , 0.60981912, 0.56521739, 0.51601928, 0.23809524,
#         0.        , 0.        ],
#        [1.        , 0.60465116, 0.51086957, 0.52055571, 0.14880952,
#         0.        , 0.        ]])

# %% [markdown]
# ### y 데이터 2차원 reshaphe, 정규화
# - 딥러닝에서 데이터 학습이 더 잘됨

# %%
# y데이터 정규화 객체
sc_y = MinMaxScaler()

# %%
y.shape
# Out:
# (392,)

# %%
y.values.reshape(-1,1)[:5]
# Out:
# array([[18.],
#        [15.],
#        [18.],
#        [16.],
#        [17.]])

# %%
y_scaled = sc_y.fit_transform(y.values.reshape(-1,1))

# %%
y_scaled[:5]
# Out:
# array([[0.2393617 ],
#        [0.15957447],
#        [0.2393617 ],
#        [0.18617021],
#        [0.21276596]])

# %% [markdown]
# ### 학습, 테스트 데이터 분할

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_scaled, 
    test_size=0.2, 
    random_state=42)

# %% [markdown]
# # 딥러닝 모델링

# %% [markdown]
# - 텐서플로 2.19 버전에서 바뀐 내용: 옵티마이저 방법을 문자열 형식 대신 객체형식으로 하면 직렬화를 더 작한다고 함.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras.optimizers import Adam

# %%
def build_model( input_dim ) :
  model = Sequential()
  model.add( keras.Input(shape=(input_dim,)) )
  model.add( Dense(64, activation='relu') )
  model.add( Dense(64, activation='relu') )
  model.add( Dense(1, activation='linear'))
    
  model.compile( Adam(learning_rate=0.001),
                 loss='mse', 
                 metrics=['mae'] )
  return model

# %%
model = build_model( X_train.shape[1] )

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 64)                  │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,737 (18.50 KB)
#  Trainable params: 4,737 (18.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
X_train.shape
# Out:
# (313, 7)

# %%
history = model.fit(
    X_train, y_train, 
    epochs = 500, 
    validation_split = 0.2,
    verbose = 0    
)

# %%
# 화면으로 출력한 결과가 기록 되어 있음
history.history.keys()
# Out:
# dict_keys(['loss', 'mae', 'val_loss', 'val_mae'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# 이 그래프를 보면 수 백번 에포크를 진행한 이후에는 모델이 거의 향상되지 않는 것 같습니다. model.fit 메서드를 수정하여 검증 점수가 향상되지 않으면 자동으로 훈련을 멈추도록 만들어 보죠. 에포크마다 훈련 상태를 점검하기 위해 EarlyStopping 콜백(callback)을 사용하겠습니다. 지정된 에포크 횟수 동안 성능 향상이 없으면 자동으로 훈련이 멈춥니다.
#
# 이 콜백에 대해 더 자세한 내용은 여기를 참고하세요.[링크 텍스트](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping)

# %% [markdown]
# # 학습 자동 중단

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
# 깡통 모델 생성
model = build_model(X_train.shape[1])

# %% [markdown]
# #

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 64)                  │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,737 (18.50 KB)
#  Trainable params: 4,737 (18.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# callback, 함수
# EarlyStopping(monitor='val_loss', mode=validation 로스 최소, patience=loss 올라가는것을 몇번 참느냐?, 
#  restore_best_weights=True weight가 가장 좋았던 상태로 되돌리기 )
early_stopping = EarlyStopping(
    monitor='val_loss', 
    mode='min', 
    patience=5, 
    restore_best_weights=True)

# %%
# 학습
history2 = model.fit(X_train, y_train, epochs = 100000, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0610 - mae: 0.2008 - val_loss: 0.0378 - val_mae: 0.1672
# Epoch 2/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0236 - mae: 0.1280 - val_loss: 0.0175 - val_mae: 0.1008
# Epoch 3/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0152 - mae: 0.0960 - val_loss: 0.0168 - val_mae: 0.1014
# Epoch 4/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0136 - mae: 0.0929 - val_loss: 0.0127 - val_mae: 0.0870
# Epoch 5/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0113 - mae: 0.0822 - val_loss: 0.0131 - val_mae: 0.0885
# Epoch 6/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0100 - mae: 0.0766 - val_loss: 0.0112 - val_mae: 0.0828
# Epoch 7/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0092 - mae: 0.0741 - val_loss: 0.0103 - val_mae: 0.0803
# Epoch 8/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0086 - mae: 0.0711 - val_loss: 0.0094 - val_mae: 0.0765
# Epoch 9/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0082 - mae: 0.0685 - val_loss: 0.0087 - val_mae: 0.0727
# Epoch 10/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0077 - mae: 0.0660 - val_loss: 0.0088 - val_mae: 0.0732
# Epoch 11/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0074 - mae: 0.0642 - val_loss: 0.0081 - val_mae: 0.0701
# Epoch 12/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0072 - mae: 0.0630 - val_loss: 0.0080 - val_mae: 0.0691
# Epoch 13/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0071 - mae: 0.0627 - val_loss: 0.0078 - val_mae: 0.0673
# Epoch 14/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0070 - mae: 0.0615 - val_loss: 0.0074 - val_mae: 0.0663
# Epoch 15/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0067 - mae: 0.0608 - val_loss: 0.0077 - val_mae: 0.0666
# Epoch 16/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0064 - mae: 0.0592 - val_loss: 0.0072 - val_mae: 0.0645
# Epoch 17/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0063 - mae: 0.0586 - val_loss: 0.0072 - val_mae: 0.0636
# Epoch 18/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0061 - mae: 0.0572 - val_loss: 0.0074 - val_mae: 0.0645
# Epoch 19/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0061 - mae: 0.0571 - val_loss: 0.0068 - val_mae: 0.0620
# Epoch 20/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0059 - mae: 0.0565 - val_loss: 0.0070 - val_mae: 0.0625
# Epoch 21/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0058 - mae: 0.0563 - val_loss: 0.0070 - val_mae: 0.0620
# Epoch 22/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0057 - mae: 0.0549 - val_loss: 0.0067 - val_mae: 0.0607
# Epoch 23/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0056 - mae: 0.0545 - val_loss: 0.0061 - val_mae: 0.0590
# Epoch 24/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0059 - mae: 0.0578 - val_loss: 0.0069 - val_mae: 0.0614
# Epoch 25/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0057 - mae: 0.0564 - val_loss: 0.0067 - val_mae: 0.0595
# Epoch 26/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0056 - mae: 0.0551 - val_loss: 0.0062 - val_mae: 0.0597
# Epoch 27/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0055 - mae: 0.0548 - val_loss: 0.0066 - val_mae: 0.0594
# Epoch 28/100000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0053 - mae: 0.0530 - val_loss: 0.0061 - val_mae: 0.0585

# %%
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# ## 평가

# %%
model.evaluate(X_test, y_test)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0056 - mae: 0.0549
# [0.005571817513555288, 0.05491272360086441]

# %%
# 2.19 버전부터는 .keras를 권장함
model.save('mpg_model.keras')

# %%
model_2 = keras.models.load_model('mpg_model.keras')
model_2.evaluate(X_test, y_test)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0056 - mae: 0.0549
# [0.005571817513555288, 0.05491272360086441]
