# %% [markdown]
# ## Image Augmentation

# %% [markdown]
# Cats v Dogs 로 다음처럼 모델링 하고, 학습시켜본다.
#
# 4 convolutional layers with 32, 64, 128 and 128 convolutions
#
# train for 100 epochs

# %% [markdown]
# - 실 세계의 이미지 데이터는 어떻게 생성했냐?
# - 현업에서는 데이터가 스토리지 서비스에 저장
# - 저장된 데이터에 이미지를 레이블링해야함.

# %% [markdown]
# # 데이터 준비

# %%
# warning 무시
import warnings
warnings.filterwarnings("ignore")

# %%
import tensorflow as tf

# 새로운 초기 가중치로 처음부터 다시 학습
tf.keras.backend.clear_session()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1788247117.028970   87251 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1788247117.358123   87251 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1788247119.379341   87251 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
import tensorflow as tf
# TensorFlow가 GPU 메모리를 처음부터 크게 선점하지 않고, 필요한 만큼 점진적으로 사용하도록 설정
gpus = tf.config.list_physical_devices("GPU")

for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# - 데이터 다운로드: https://drive.google.com/file/d/1wr4e_7P2d4ICN11ecNb8aqhbakD4ahK6/view?usp=sharing

# %%
import os, zipfile, pathlib
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %%
# 윈도우 환경
import os
import zipfile
import urllib.request

# %%
# 압축을 풀 위치
data_path = "./datas_dnn"
os.makedirs(data_path, exist_ok=True)
extract_root = pathlib.Path(data_path)

# %%
# uv add gdown

# %%
# import gdown  
# # 데이터의 위치
# url = "https://drive.google.com/uc?id=1wr4e_7P2d4ICN11ecNb8aqhbakD4ahK6"
# file_id = "1wr4e_7P2d4ICN11ecNb8aqhbakD4ahK6"
# output = "datas_dnn/cats_and_dogs_filtered.zip" # 저장 위치 및 저장할 파일 이름
# zip_path = gdown.download(id=file_id, output=output, quiet=False)

# %%
# 압축풀기
zip_path = "datas_dnn/cats_and_dogs_filtered.zip"
with zipfile.ZipFile(zip_path, 'r') as zip_file:
    zip_file.extractall(extract_root)

# %% [markdown]
# - 현실 데이터는 이미지 사이즈가 제각각임
# - 폴더명이 레이블 이름

# %%
IMG_SIZE = 150
IMAGE_SHAPE= (IMG_SIZE, IMG_SIZE, 3)

# %%
BATCH_SIZE = 20

# %%
SEED = 1337

# %%
BASE_DIR = extract_root / 'cats_and_dogs_filtered'
train_dir  = BASE_DIR / 'train'
test_dir = BASE_DIR / 'validation'

# %%
train_dir
# Out:
# PosixPath('datas_dnn/cats_and_dogs_filtered/train')

# %%
test_dir
# Out:
# PosixPath('datas_dnn/cats_and_dogs_filtered/validation')

# %%
# 학습 데이터 셋만들기
train_ds = keras.utils.image_dataset_from_directory(
    train_dir,            # 학습 데이터 위치
    image_size = (IMG_SIZE, IMG_SIZE), # 이미지 사이즈
    batch_size = BATCH_SIZE,           # batch 크기
    shuffle=True,                      # shuffle
    seed=SEED
)
# Out:
# Found 2000 files belonging to 2 classes.
# I0000 00:00:1788247123.371133   87251 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5563 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
# 테스트 데이터셋 만들기
test_ds = keras.utils.image_dataset_from_directory(
    test_dir,
    image_size = (IMG_SIZE, IMG_SIZE) ,
    batch_size = BATCH_SIZE,
    shuffle=True,
)
# Out:
# Found 1000 files belonging to 2 classes.

# %%
# target 값 가져오기(폴더 이름)
class_names = train_ds.class_names

# %%
class_names
# Out:
# ['cats', 'dogs']

# %% [markdown]
# # 성능 최적화를 위한 코드(GPU 사용시)
# - 다음 배치를 백그라운드에서 미리 준비하라는 코드 작성
# - 학습 효과를 높이기 위해
# - 데이터 증강, 데이터 플립,

# %%
# TensorFlow가 prefetch 버퍼 크기를 자동으로 조절해주는 옵션
AUTOTUNE = tf.data.AUTOTUNE

# %%
# 학습 중 다음 배치(batch)를 백그라운드에서 미리 준비(학습 속도 빨라짐)
train_ds = train_ds.prefetch(AUTOTUNE)

# %%
# 검증(validation) 데이터도 동일하게 최적화하는 과정
test_ds = test_ds.prefetch(AUTOTUNE)

# %% [markdown]
# ## 데이터 증강

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.1),
        layers.RandomTranslation(0.1, 0.1)
    ],
    name = 'data_augmentation',
)

# %% [markdown]
# # 학습 모델 만들기

# %% [markdown]
# ## 모델 설계

# %%
from tensorflow import keras
from tensorflow.keras import layers, Sequential

# %%
def build_model(input_shape):
    return Sequential(
        [
            layers.Input(shape=input_shape),
            data_augmentation,  # 데이터 증강
            layers.Rescaling(1.0/255.0),  # 스케일링
            layers.Conv2D(32, 3, activation='relu'),
            layers.MaxPooling2D(2,2),
            layers.Conv2D(64, 3, activation='relu'),
            layers.MaxPooling2D(2,2),
            layers.Conv2D(128, 3, activation='relu'), 
            layers.MaxPooling2D(2,2),

            # 출력층 전에 1차원으로 변경해야함.
            layers.Flatten(),
            layers.Dense(512, activation='relu'),
            layers.Dropout(0.2), 
            layers.Dense(2, activation='softmax')  # 출력층 2개
        ],
        name="simple_cnn",
    )

# %%
model = build_model(IMAGE_SHAPE)

# %%
model.summary()
# Out:
# Model: "simple_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ data_augmentation (Sequential)  │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 72, 72, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 34, 34, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 17, 17, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 36992)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    18,940,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │         1,026 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,034,690 (72.61 MB)
#  Trainable params: 19,034,690 (72.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer=keras.optimizers.Adam(), 
            loss= keras.losses.SparseCategoricalCrossentropy(),
            metrics=['accuracy'])

# %%
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=5, # 시간 많이 걸림
                                           # patience=3,
                                           restore_best_weights=True)

# %% [markdown]
# ## 모델 학습

# %%
history = model.fit(
    train_ds, 
    validation_data=test_ds, 
    epochs=100, 
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# I0000 00:00:1788247126.632899   87392 cuda_dnn.cc:461] Loaded cuDNN version 92501
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - accuracy: 0.5095 - loss: 0.7482 - val_accuracy: 0.5650 - val_loss: 0.6883
# Epoch 2/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.5725 - loss: 0.6854 - val_accuracy: 0.5890 - val_loss: 0.6705
# Epoch 3/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.5925 - loss: 0.6657 - val_accuracy: 0.5960 - val_loss: 0.6531
# Epoch 4/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.6170 - loss: 0.6626 - val_accuracy: 0.6300 - val_loss: 0.6623
# Epoch 5/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.6500 - loss: 0.6490 - val_accuracy: 0.6250 - val_loss: 0.6511
# Epoch 6/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.6605 - loss: 0.6280 - val_accuracy: 0.6770 - val_loss: 0.6086
# Epoch 7/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.6800 - loss: 0.6079 - val_accuracy: 0.6720 - val_loss: 0.6030
# Epoch 8/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.6735 - loss: 0.6136 - val_accuracy: 0.6630 - val_loss: 0.6410
# Epoch 9/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.6705 - loss: 0.6123 - val_accuracy: 0.6590 - val_loss: 0.6195
# Epoch 10/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.6870 - loss: 0.5891 - val_accuracy: 0.6910 - val_loss: 0.5771
# Epoch 11/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.6810 - loss: 0.6013 - val_accuracy: 0.7050 - val_loss: 0.5597
# Epoch 12/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.7060 - loss: 0.5697 - val_accuracy: 0.7000 - val_loss: 0.5649
# Epoch 13/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.7075 - loss: 0.5643 - val_accuracy: 0.7080 - val_loss: 0.5714
# Epoch 14/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.7115 - loss: 0.5547 - val_accuracy: 0.7170 - val_loss: 0.5495
# Epoch 15/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.7275 - loss: 0.5467 - val_accuracy: 0.6960 - val_loss: 0.5683
# Epoch 16/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.7275 - loss: 0.5398 - val_accuracy: 0.6900 - val_loss: 0.6186
# Epoch 17/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7360 - loss: 0.5245 - val_accuracy: 0.7200 - val_loss: 0.5756
# Epoch 18/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.7380 - loss: 0.5302 - val_accuracy: 0.7030 - val_loss: 0.5819
# Epoch 19/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.7200 - loss: 0.5421 - val_accuracy: 0.7160 - val_loss: 0.5565

# %% [markdown]
# # 모델 평가

# %%
model.evaluate(test_ds)
# Out:
#  1/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7500 - loss: 0.5551
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7170 - loss: 0.5495
# [0.54947829246521, 0.7170000076293945]

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.show()

# %% [markdown]
# # 모델 저장하기

# %%
import os
os.makedirs('models', exist_ok=True)
model.save('models/my_dog_cat_model.keras')

# %% [markdown]
# # 일반화

# %%
# 학습한 모델 불러오기
model = tf.keras.models.load_model("models/my_dog_cat_model.keras")

# 클래스 이름
class_names = ["cat", "dog"]

# %% [markdown]
# ## 이미지 확인

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# 예측하고 싶은 이미지 경로
img_path = "images/cat.jpg"

img = mpimg.imread(img_path)
plt.imshow(img)
plt.axis('off')   # 축 제거 (선택)
plt.show()

# %%
import numpy as np
# 1) 이미지 로딩
img = tf.keras.utils.load_img(img_path, target_size=(IMG_SIZE, IMG_SIZE))

# 2) 배열로 변환
img_array = tf.keras.utils.img_to_array(img)

# 3) 0~1 범위 일반화
img_array = img_array / 255.0

# 4) 배치 차원 추가 (1, 150,150,3)
img_array = np.expand_dims(img_array, axis=0)

# %%
import tensorflow as tf
import numpy as np

IMG_SIZE = 150

def load_and_preprocess_image(img_path):
    # 1) 이미지 로드
    img = tf.keras.utils.load_img(img_path, target_size=(IMG_SIZE, IMG_SIZE))
    
    # 2) 배열로 변환
    img_array = tf.keras.utils.img_to_array(img)
    
    # 3) 0~1 범위 일반화
    img_array = img_array / 255.0
    
    # 4) 배치 차원 추가 (1, 150,150,3)
    img_array = np.expand_dims(img_array, axis=0)
    return img_array


def predict_image(model, img_path, class_names):
    img = load_and_preprocess_image(img_path)
    pred = model.predict(img)
    print(pred)
    # 클래스 index
    pred_idx = np.argmax(pred, axis=1)[0]
    print(pred_idx)
    pred_class = class_names[pred_idx]
    pred_prob = np.max(pred)

    print(f"예측 클래스: {pred_class}")
    print(f"확률: {pred_prob:.4f}")

# %%
# 학습한 모델 불러오기
model = tf.keras.models.load_model("models/my_dog_cat_model.keras")

# 클래스 이름
class_names = ["cat", "dog"]

# 예측하고 싶은 이미지 경로
img_path = "images/cat.jpg"

predict_image(model, img_path, class_names)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# [[0.89392203 0.10607799]]
# 0
# 예측 클래스: cat
# 확률: 0.8939
