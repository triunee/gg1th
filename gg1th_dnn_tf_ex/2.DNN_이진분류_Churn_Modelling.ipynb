# %% [markdown]
# ### 금융상품 갱신 여부 예측하는 DNN
# Churn_Modelling.csv 파일을 보면, 고객 정보와 해당 고객이 금융상품을 갱신했는지 안했는지의 여부에 대한 데이터가 있다.
#
# 이 데이터를 가지고 갱신여부를 예측하는 딥러닝을 구성하시오.

# %% [markdown]
# - 통신사: 고객이 다음 달에 통신 서비스를 해지할지 예측
# - OTT: 구독자가 구독을 취소할 가능성 예측
# - 은행: 고객이 계좌나 금융상품을 이탈할 가능성 예측
# - 쇼핑몰: 고객이 장기간 구매하지 않을 가능성 예측
# 머신러닝 관점에서는 보통 이진 분류 문제이다.

# %% [markdown]
# # Neural Networks and Deep Learning

# %%
import os
import warnings

warnings.filterwarnings("ignore")
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import tensorflow as tf
print(tf.__version__)
# Out:
# 2.21.0

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
import os
# from google.colab import drive
# drive.mount('/content/drive')
# os.chdir('/content/drive/MyDrive/data')

# %%
df = pd.read_csv('./datas_dnn/Churn_Modelling.csv')

# %%
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.head(4)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0

# %%
y = df['Exited']

# %%
X = df.loc[ :  , 'CreditScore' : 'EstimatedSalary' ]

# %%
y.unique()
# Out:
# array([1, 0])

# %%
X.head(3)
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57

# %%
X['Geography'].unique()
# Out:
# <StringArray>
# ['France', 'Spain', 'Germany']
# Length: 3, dtype: str

# %%
X['Gender'].unique()
# Out:
# <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str

# %%
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
ct = ColumnTransformer( [ ('onehot', OneHotEncoder(), [1] ) , ('label' , OrdinalEncoder(), [2] ) ] , remainder='passthrough' )

# %%
X_ct = ct.fit_transform(X)

# %%
X_ct[ 0 , : ]
# Out:
# array([1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        6.1900000e+02, 4.2000000e+01, 2.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 1.0000000e+00, 1.0134888e+05])

# %%
X.head(3)
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57

# %%
X_ct
# Out:
# array([[1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         1.0000000e+00, 1.0134888e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 1.1254258e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 1.1393157e+05],
#        ...,
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 4.2085580e+04],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 9.2888520e+04],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 3.8190780e+04]], shape=(10000, 12))

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
X_ct
# Out:
# array([[1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         1.0000000e+00, 1.0134888e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 1.1254258e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 1.1393157e+05],
#        ...,
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 4.2085580e+04],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 9.2888520e+04],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 3.8190780e+04]], shape=(10000, 12))

# %%
mms = MinMaxScaler()

# %%
X_scaled = mms.fit_transform(X_ct)

# %%
X_scaled.shape
# Out:
# (10000, 12)

# %%
X_scaled[0, :]
# Out:
# array([1.        , 0.        , 0.        , 0.        , 0.538     ,
#        0.32432432, 0.2       , 0.        , 0.        , 1.        ,
#        1.        , 0.50673489])

# %%
X.head(1)
# Out:
#    CreditScore Geography  Gender  Age  Tenure  Balance  NumOfProducts  \
# 0          619    France  Female   42       2      0.0              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88

# %%
from sklearn.model_selection import train_test_split

# %%
X_scaled.shape
# Out:
# (10000, 12)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, 
    test_size=0.2, 
    random_state=42)

# %%
# modeling

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
X_train.shape
# Out:
# (8000, 12)

# %%
model = Sequential()

# %%
model.add(  keras.Input( shape=(12, ) )   )

# %%
model.add(  Dense(units= 6, activation='relu' )   )

# %%
model.add( Dense(units= 8, activation='relu'))

# %%
model.add( Dense(units= 1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 6)              │            78 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 8)              │            56 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 143 (572.00 B)
#  Trainable params: 143 (572.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# compile

# %%
model.compile( optimizer='adam', loss= 'binary_crossentropy', metrics= ['accuracy']  )

# %%
model.fit(X_train, y_train, epochs= 20, batch_size= 10 )
# Out:
# Epoch 1/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 105us/step - accuracy: 0.7738 - loss: 0.5104
# Epoch 2/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7971 - loss: 0.4684
# Epoch 3/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8049 - loss: 0.4501
# Epoch 4/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8145 - loss: 0.4315
# Epoch 5/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8235 - loss: 0.4125
# Epoch 6/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8307 - loss: 0.3957
# Epoch 7/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8356 - loss: 0.3850
# Epoch 8/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8390 - loss: 0.3781
# Epoch 9/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8421 - loss: 0.3736
# Epoch 10/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8422 - loss: 0.3717
# Epoch 11/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8431 - loss: 0.3692
# Epoch 12/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8430 - loss: 0.3678
# Epoch 13/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8424 - loss: 0.3660
# Epoch 14/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8445 - loss: 0.3647
# Epoch 15/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8451 - loss: 0.3628
# Epoch 16/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ -0s -525us/step - accuracy: 0.8459 - loss: 0.3611
# Epoch 17/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8482 - loss: 0.3601
# Epoch 18/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8476 - loss: 0.3581
# Epoch 19/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8506 - loss: 0.3566
# Epoch 20/20
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8514 - loss: 0.3549

# %%
X_train.shape
# Out:
# (8000, 12)

# %%
8000 / 250
# Out:
# 32.0

# %%
model.evaluate(X_test, y_test )
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8525 - loss: 0.3550
# [0.3550163209438324, 0.8525000214576721]

# %%
# 정확도 84% 모델완성.

# %%
y_pred = model.predict(X_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_test[:10]
# Out:
# 6252    0
# 4684    0
# 1731    0
# 4742    0
# 4521    0
# 6340    0
# 576     0
# 5202    1
# 6363    0
# 439     0
# Name: Exited, dtype: int64

# %%
y_pred[:10]
# Out:
# array([[0.05797269],
#        [0.02061148],
#        [0.128433  ],
#        [0.2001011 ],
#        [0.06600551],
#        [0.01002812],
#        [0.2507381 ],
#        [0.28882182],
#        [0.39141706],
#        [0.5635937 ]], dtype=float32)

# %%
y_pred = (y_pred > 0.5).astype(int)

# %%
y_pred[:5]
# Out:
# array([[0],
#        [0],
#        [0],
#        [0],
#        [0]])

# %%
y_pred = y_pred.flatten()

# %%
(y_test==y_pred).sum()/len(y_test)
# Out:
# np.float64(0.8525)

# %% [markdown]
# ## 다음 신규 데이터를 통해 분류해 보자
#
# - Geography: France
# - Credit Score: 600
# - Gender: Male
# - Age: 40
# - Tenure: 3
# - Balance: 60000
# - Number of Products: 2
# - Has Credit Card: Yes
# - Is Active Member: Yes
# - Estimated Salary: 50000

# %%
X.head(2)
# Out:
#    CreditScore Geography  Gender  Age  Tenure   Balance  NumOfProducts  \
# 0          619    France  Female   42       2      0.00              1
# 1          608     Spain  Female   41       1  83807.86              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58

# %%
new_data = [ {'CreditScore' : 600, 
              'Geography' : 'France' , 
              'Gender' : 'Male', 
              'Age': 40, 
              'Tenure' : 3, 
              'Balance' : 60000, 
              'NumOfProducts':2, 
              'HasCrCard' : 1, 
              'IsActiveMember' : 1,
              'EstimatedSalary' : 50000 } ]

# %%
df_new = pd.DataFrame(new_data)

# %%
df_new
# Out:
#    CreditScore Geography Gender  Age  Tenure  Balance  NumOfProducts  \
# 0          600    France   Male   40       3    60000              2
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1            50000

# %%
import joblib
import os

pre_path = './preprocessor'
os.makedirs(pre_path, exist_ok=True)

# %%
# column transformer 저장
joblib.dump(ct, f'{pre_path}/ct.pkl')

# min max scaler 저장
joblib.dump(mms, f'{pre_path}/mms.pkl')
# Out:
# ['./preprocessor/mms.pkl']

# %%
loaded_ct = joblib.load(f'{pre_path}/ct.pkl')
loaded_mms = joblib.load(f'{pre_path}/mms.pkl')

new_data_ct = loaded_ct.transform(df_new)
new_data_mms = loaded_mms.transform(new_data_ct)

# %%
new_data_ct
# Out:
# array([[1.e+00, 0.e+00, 0.e+00, 1.e+00, 6.e+02, 4.e+01, 3.e+00, 6.e+04,
#         2.e+00, 1.e+00, 1.e+00, 5.e+04]])

# %%
new_data_mms
# Out:
# array([[1.        , 0.        , 0.        , 1.        , 0.5       ,
#         0.2972973 , 0.3       , 0.23914092, 0.33333333, 1.        ,
#         1.        , 0.24996597]])

# %%
y_pred = model.predict( new_data_mms )
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %%
y_pred[0][0]
# Out:
# np.float32(0.028653491)

# %%
(y_pred > 0.5).astype(int)
# Out:
# array([[0]])

# %%
# modes 폴더가 없으면 생성
model_path = './models'
os.makedirs(model_path, exist_ok=True)

# %%
model.save(f'{model_path}/churn_model.keras')

# %%
import keras
model = keras.models.load_model(f'{model_path}/churn_model.keras')
model.evaluate(X_test, y_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8525 - loss: 0.3550
# [0.3550163209438324, 0.8525000214576721]

# %%
# 학습 완료 했으면, gpu 메모리 해제, restart kernel

# %% [markdown]
# ### 용어 정리
#
# epoch
#
# - 한 번의 epoch는 신경망에서 전체 데이터 셋에 대해 forward pass/backward pass 과정을 거친 것을 말함. 즉, 전체 데이터 셋에 대해 한 번 학습을 완료한 상태
#
#
# batch_size
#
# 메모리의 한계와 속도 저하 때문에 대부분의 경우에는 한 번의 epoch에서 모든 데이터를 한꺼번에 집어넣을 수는 없습니다. 그래서 데이터를 나누어서 주게 되는데 이때 몇 번 나누어서 주는가를 iteration, 각 iteration마다 주는 데이터 사이즈를 batch size라고 합니다.
#
# 출처: https://www.slideshare.net/w0ong/ss-82372826
