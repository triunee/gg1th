# %% [markdown]
# #  와인데이터 분석2

# %% [markdown]
# - datas/winemag-data.csv

# %%
import pandas as pd
pd.__version__
# Out:
# '3.0.5'

# %%
# 로컬에서 로딩

data = "./datas/winemag-data.csv"
# 첫번째 컬럼을 index에 사용
df = pd.read_csv(data, index_col = 0 )
df.head(2)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
# 1      87   15.0              Douro      NaN      NaN     Roger Voss
#
#   taster_twitter_handle                                          title  \
# 0          @kerinokeefe              Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos

# %%
# 1. title 컬럼에 데이터가 비어있는것이 있는지 확인한다.
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   country                129908 non-null  str
#  1   description            129971 non-null  str
#  2   designation            92506 non-null   str
#  3   points                 129971 non-null  int64
#  4   price                  120975 non-null  float64
#  5   province               129908 non-null  str
#  6   region_1               108724 non-null  str
#  7   region_2               50511 non-null   str
#  8   taster_name            103727 non-null  str
#  9   taster_twitter_handle  98758 non-null   str
#  10  title                  129971 non-null  str
#  11  variety                129970 non-null  str
#  12  winery                 129971 non-null  str
# dtypes: float64(1), int64(1), str(11)
# memory usage: 12.9 MB

# %%
df.notna().sum()
# Out:
# country                  129908
# description              129971
# designation               92506
# points                   129971
# price                    120975
# province                 129908
# region_1                 108724
# region_2                  50511
# taster_name              103727
# taster_twitter_handle     98758
# title                    129971
# variety                  129970
# winery                   129971
# dtype: int64

# %%
df['title'].unique()
# Out:
# <StringArray>
# [                                                                    'Nicosia 2013 Vulkà Bianco  (Etna)',
#                                                          'Quinta dos Avidagos 2011 Avidagos Red (Douro)',
#                                                          'Rainstorm 2013 Pinot Gris (Willamette Valley)',
#                                    'St. Julian 2013 Reserve Late Harvest Riesling (Lake Michigan Shore)',
#                    'Sweet Cheeks 2012 Vintner's Reserve Wild Child Block Pinot Noir (Willamette Valley)',
#                                                  'Tandem 2011 Ars In Vitro Tempranillo-Merlot (Navarra)',
#                                                       'Terre di Giurfo 2013 Belsito Frappato (Vittoria)',
#                                                                  'Trimbach 2012 Gewurztraminer (Alsace)',
#                                                    'Heinz Eifel 2013 Shine Gewürztraminer (Rheinhessen)',
# ...

# %%
df['title'].nunique()
# Out:
# 118840

# %%
# 2. 인덱스를 title 컬름으로 변경
df.set_index('title').info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 129971 entries, Nicosia 2013 Vulkà Bianco  (Etna) to Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caroline Gewurztraminer (Alsace)
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   country                129908 non-null  str
#  1   description            129971 non-null  str
#  2   designation            92506 non-null   str
#  3   points                 129971 non-null  int64
#  4   price                  120975 non-null  float64
#  5   province               129908 non-null  str
#  6   region_1               108724 non-null  str
#  7   region_2               50511 non-null   str
#  8   taster_name            103727 non-null  str
#  9   taster_twitter_handle  98758 non-null   str
#  10  variety                129970 non-null  str
#  11  winery                 129971 non-null  str
# dtypes: float64(1), int64(1), str(10)
# memory usage: 12.9+ MB

# %%
df = df.set_index('title')
df
# Out:
#                                                      country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)             US
# St. Julian 2013 Reserve Late Harvest Riesling (...        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...        US
# ...                                                      ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...   Germany
# Citation 2004 Pinot Noir (Oregon)                         US
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)    France
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# ...

# %% [markdown]
# ## 문제1

# %%
# 먼저 데이터가 비어있는것이 있는지 확인한다.
# 가격이 있는 데이터만  가져온다
# 새로운 컬럼 critic 만들고, everyone 이라고 값 넣는다
# 포인트 컬럼은 수치로 되어있다. 이 컬럼의 기초통계데이터를 확인하시오. (평균, 최대 최소 등)
# taster_name 컬럼은 사람 이름으로 되어있다. 몇명의 사람들이 평가를 한것인까?
# 포인트의 평균을 구하시오
# 테이스터들의 이름을 전부 확인하시오

# %%
# 먼저 데이터가 비어있는것이 있는지 확인한다.
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 129971 entries, Nicosia 2013 Vulkà Bianco  (Etna) to Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caroline Gewurztraminer (Alsace)
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   country                129908 non-null  str
#  1   description            129971 non-null  str
#  2   designation            92506 non-null   str
#  3   points                 129971 non-null  int64
#  4   price                  120975 non-null  float64
#  5   province               129908 non-null  str
#  6   region_1               108724 non-null  str
#  7   region_2               50511 non-null   str
#  8   taster_name            103727 non-null  str
#  9   taster_twitter_handle  98758 non-null   str
#  10  variety                129970 non-null  str
#  11  winery                 129971 non-null  str
# dtypes: float64(1), int64(1), str(10)
# memory usage: 12.9+ MB

# %%
df.isna().sum()
# Out:
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# variety                      1
# winery                       0
# dtype: int64

# %%
# nan의 갯수의 합
df.isna().sum().sum()
# Out:
# np.int64(204752)

# %% [markdown]
# - 가격이 있는 데이터만  가져온다

# %%
df['price'].notna()
# Out:
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                                                                        False
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                                                             True
# Rainstorm 2013 Pinot Gris (Willamette Valley)                                                             True
# St. Julian 2013 Reserve Late Harvest Riesling (Lake Michigan Shore)                                       True
# Sweet Cheeks 2012 Vintner's Reserve Wild Child Block Pinot Noir (Willamette Valley)                       True
#                                                                                                          ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 Brauneberger Juffer-Sonnenuhr Spätlese Riesling (Mosel)     True
# Citation 2004 Pinot Noir (Oregon)                                                                         True
# ...

# %%
# 가격이 있는 데이터만  가져온다
df.loc[df['price'].notna(), ]
# Out:
#                                                      country  \
# title
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)             US
# St. Julian 2013 Reserve Late Harvest Riesling (...        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...        US
# Tandem 2011 Ars In Vitro Tempranillo-Merlot (Na...     Spain
# ...                                                      ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...   Germany
# Citation 2004 Pinot Noir (Oregon)                         US
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)    France
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description  \
# title
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       This is ripe and fruity, a wine that is smooth...
# ...

# %%
# 가격이 있는 데이터의 갯수
df.loc[df['price'].notna(), ].shape
# Out:
# (120975, 12)

# %%
# 새로운 컬럼 critic 만들고, everyone 이라고 값 넣는다
df['critic'] = 'everyone'
df.head()
# Out:
#                                                      country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)             US
# St. Julian 2013 Reserve Late Harvest Riesling (...        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...        US
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       This is ripe and fruity, a wine that is smooth...
# Rainstorm 2013 Pinot Gris (Willamette Valley)       Tart and snappy, the flavors of lime flesh and...
# St. Julian 2013 Reserve Late Harvest Riesling (...  Pineapple rind, lemon pith and orange blossom ...
# ...

# %%
# 포인트 컬럼은 수치로 되어있다. 이 컬럼의 기초통계데이터를 확인하시오. (평균, 최대 최소 등)
df['points'].mean()
# Out:
# np.float64(88.44713820775404)

# %%
df['points'].max()
# Out:
# np.int64(100)

# %%
df['points'].min()
# Out:
# np.int64(80)

# %%
# nan 이 한개 있음
df['taster_name'].unique()
# Out:
# <StringArray>
# [     'Kerin O’Keefe',         'Roger Voss',       'Paul Gregutt',
#  'Alexander Peartree',  'Michael Schachner', 'Anna Lee C. Iijima',
#      'Virginie Boone',      'Matt Kettmann',                  nan,
#    'Sean P. Sullivan',         'Jim Gordon',     'Joe Czerwinski',
#    'Anne Krebiehl MW',      'Lauren Buzzeo',      'Mike DeSimone',
#        'Jeff Jenssen',    'Susan Kostrzewa',       'Carrie Dykes',
#         'Fiona Adams',  'Christina Pickard']
# Length: 20, dtype: str

# %%
# taster_name 컬럼은 사람 이름으로 되어있다. 몇명의 사람들이 평가를 한것인까?
df['taster_name'].unique().__len__()
# Out:
# 20

# %%
df['taster_name'].nunique()
# Out:
# 19

# %%
# 포인트의 평균을 구하시오
df['points'].mean()
# Out:
# np.float64(88.44713820775404)

# %%
df['points'].describe()
# Out:
# count    129971.000000
# mean         88.447138
# std           3.039730
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          91.000000
# max         100.000000
# Name: points, dtype: float64

# %%
# taster_name 컬럼은 사람 이름으로 되어있다. 몇명의 사람들이 평가를 한것인까?
# 테이스터들의 이름을 전부 확인하시오

# %%
df['taster_name']
# Out:
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                                                                             Kerin O’Keefe
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                                                                    Roger Voss
# Rainstorm 2013 Pinot Gris (Willamette Valley)                                                                  Paul Gregutt
# St. Julian 2013 Reserve Late Harvest Riesling (Lake Michigan Shore)                                      Alexander Peartree
# Sweet Cheeks 2012 Vintner's Reserve Wild Child Block Pinot Noir (Willamette Valley)                            Paul Gregutt
#                                                                                                                 ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 Brauneberger Juffer-Sonnenuhr Spätlese Riesling (Mosel)    Anna Lee C. Iijima
# ...

# %%
# 테이스터들의 이름을 전부 확인하시오, nan  이 포함 되어 있음
unique_test = df['taster_name'].unique()
print(unique_test)
len(unique_test)
# Out:
# <StringArray>
# [     'Kerin O’Keefe',         'Roger Voss',       'Paul Gregutt',
#  'Alexander Peartree',  'Michael Schachner', 'Anna Lee C. Iijima',
#      'Virginie Boone',      'Matt Kettmann',                  nan,
#    'Sean P. Sullivan',         'Jim Gordon',     'Joe Czerwinski',
#    'Anne Krebiehl MW',      'Lauren Buzzeo',      'Mike DeSimone',
#        'Jeff Jenssen',    'Susan Kostrzewa',       'Carrie Dykes',
#         'Fiona Adams',  'Christina Pickard']
# Length: 20, dtype: str
# 20

# %%
# 테이스터들의 이름을 전부 확인하시오
unique_test = unique_test[pd.notna(unique_test)]
print(unique_test)
print(len(unique_test))
# Out:
# <StringArray>
# [     'Kerin O’Keefe',         'Roger Voss',       'Paul Gregutt',
#  'Alexander Peartree',  'Michael Schachner', 'Anna Lee C. Iijima',
#      'Virginie Boone',      'Matt Kettmann',   'Sean P. Sullivan',
#          'Jim Gordon',     'Joe Czerwinski',   'Anne Krebiehl MW',
#       'Lauren Buzzeo',      'Mike DeSimone',       'Jeff Jenssen',
#     'Susan Kostrzewa',       'Carrie Dykes',        'Fiona Adams',
#   'Christina Pickard']
# Length: 19, dtype: str
# 19

# %% [markdown]
# ##  문제2

# %%
# 각 테이스터들은, 각각 몇개의 와인을 테스트 했는지 확인하시오. ( 테스터 이름, 갯수 )
# 포인트의 평균을 구하고, 리뷰의 포인트값이, 평균보다 큰 데이터 (즉, 평가가 좋은 와인) 만 가져오시오.
# points 컬럼의 median 값은?
# 각 국가별로는 몇개의 리뷰가 있는지, 각국가별 리뷰수를 구하시오.
# 나는 경제적이므로, 가격대비 포인트가 가장 큰 와인을 사려한다. 해당 와인의 title은?

# %%
df.head(2)
# Out:
#                                                 country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                 Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portugal
#
#                                                                                      description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  This is ripe and fruity, a wine that is smooth...
#
#                                                 designation  points  price  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Vulkà Bianco      87    NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)      Avidagos      87   15.0
#
#                                                         province region_1  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Sicily & Sardinia     Etna
# Quinta dos Avidagos 2011 Avidagos Red (Douro)              Douro      NaN
#
# ...

# %%
df['taster_name'].head(5)
# Out:
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                                                           Kerin O’Keefe
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                                                  Roger Voss
# Rainstorm 2013 Pinot Gris (Willamette Valley)                                                Paul Gregutt
# St. Julian 2013 Reserve Late Harvest Riesling (Lake Michigan Shore)                    Alexander Peartree
# Sweet Cheeks 2012 Vintner's Reserve Wild Child Block Pinot Noir (Willamette Valley)          Paul Gregutt
# Name: taster_name, dtype: str

# %%
# 각 테이스터들은, 각각 몇개의 와인을 테스트 했는지 확인하시오. ( 테스터 이름, 갯수 )
df['taster_name'].value_counts()
# Out:
# taster_name
# Roger Voss            25514
# Michael Schachner     15134
# Kerin O’Keefe         10776
# Virginie Boone         9537
# Paul Gregutt           9532
# Matt Kettmann          6332
# Joe Czerwinski         5147
# Sean P. Sullivan       4966
# Anna Lee C. Iijima     4415
# Jim Gordon             4177
# Anne Krebiehl MW       3685
# Lauren Buzzeo          1835
# Susan Kostrzewa        1085
# Mike DeSimone           514
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#                                                 country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                 Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portugal
#
#                                                                                      description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  This is ripe and fruity, a wine that is smooth...
#
#                                                 designation  points  price  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Vulkà Bianco      87    NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)      Avidagos      87   15.0
#
#                                                         province region_1  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Sicily & Sardinia     Etna
# Quinta dos Avidagos 2011 Avidagos Red (Douro)              Douro      NaN
#
# ...

# %%
# 포인트의 평균을 구하고, 리뷰의 포인트값이, 평균보다 큰 데이터 (즉, 평가가 좋은 와인) 만 가져오시오.
df['points'].mean()
# Out:
# np.float64(88.44713820775404)

# %%
df['points'] > df['points'].mean()
# Out:
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                                                                        False
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                                                            False
# Rainstorm 2013 Pinot Gris (Willamette Valley)                                                            False
# St. Julian 2013 Reserve Late Harvest Riesling (Lake Michigan Shore)                                      False
# Sweet Cheeks 2012 Vintner's Reserve Wild Child Block Pinot Noir (Willamette Valley)                      False
#                                                                                                          ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 Brauneberger Juffer-Sonnenuhr Spätlese Riesling (Mosel)     True
# Citation 2004 Pinot Noir (Oregon)                                                                         True
# ...

# %%
# 리뷰의 포인트값이, 평균보다 큰 데이터 
df.loc[df['points'] > df['points'].mean(), :]
# Out:
#                                                       country  \
# title
# Dopff & Irion 2004 Schoenenbourg Grand Cru Vend...     France
# Ceretto 2003 Bricco Rocche Prapó  (Barolo)              Italy
# Matrix 2007 Stuhlmuller Vineyard Chardonnay (Al...         US
# Mauritson 2007 Rockpile Cemetary Vineyard Zinfa...         US
# Henry's Drive Vignerons 2006 Parson's Flat Shir...  Australia
# ...                                                       ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...    Germany
# Citation 2004 Pinot Noir (Oregon)                          US
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)     France
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)          France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...     France
#
#                                                                                           description  \
# title
# Dopff & Irion 2004 Schoenenbourg Grand Cru Vend...  Medium-gold in color. Complex and inviting nos...
# ...

# %%
# points 컬럼의 median 값은?
df['points'].median()
# Out:
# np.float64(88.0)

# %%
df.head(2)
# Out:
#                                                 country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                 Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portugal
#
#                                                                                      description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  This is ripe and fruity, a wine that is smooth...
#
#                                                 designation  points  price  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Vulkà Bianco      87    NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)      Avidagos      87   15.0
#
#                                                         province region_1  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Sicily & Sardinia     Etna
# Quinta dos Avidagos 2011 Avidagos Red (Douro)              Douro      NaN
#
# ...

# %%
# 각 국가별로는 몇개의 리뷰가 있는지, 각국가별 리뷰수를 구하시오.
pd.DataFrame(df.groupby('country')['description'].count())
# Out:
#                         description
# country
# Argentina                      3800
# Armenia                           2
# Australia                      2329
# Austria                        3345
# Bosnia and Herzegovina            2
# Brazil                           52
# Bulgaria                        141
# Canada                          257
# Chile                          4472
# China                             1
# Croatia                          73
# Cyprus                           11
# Czech Republic                   12
# Egypt                             1
# England                          74
# France                        22093
# Georgia                          86
# Germany                        2165
# Greece                          466
# Hungary                         146
# India                             9
# Israel                          505
# Italy                         19540
# Lebanon                          35
# Luxembourg                        6
# ...

# %%
df.head(2)
# Out:
#                                                 country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                 Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portugal
#
#                                                                                      description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  This is ripe and fruity, a wine that is smooth...
#
#                                                 designation  points  price  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Vulkà Bianco      87    NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)      Avidagos      87   15.0
#
#                                                         province region_1  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Sicily & Sardinia     Etna
# Quinta dos Avidagos 2011 Avidagos Red (Douro)              Douro      NaN
#
# ...

# %%
# 나는 경제적이므로, 가격대비 포인트가 가장 큰 와인을 사려한다. 해당 와인의 title은?
# 가성비 높은 와인 찾기

df['price']
# Out:
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                                                                         NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                                                            15.0
# Rainstorm 2013 Pinot Gris (Willamette Valley)                                                            14.0
# St. Julian 2013 Reserve Late Harvest Riesling (Lake Michigan Shore)                                      13.0
# Sweet Cheeks 2012 Vintner's Reserve Wild Child Block Pinot Noir (Willamette Valley)                      65.0
#                                                                                                          ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 Brauneberger Juffer-Sonnenuhr Spätlese Riesling (Mosel)    28.0
# Citation 2004 Pinot Noir (Oregon)                                                                        75.0
# ...

# %%
# 가격대비 포인트가 가장 큰 와인을 사려한다.
# 가성비 : 포인트 / 가격
df['cost-effect'] = (df['points'] / df['price'])

# %%
df['cost-effect'].max()
# Out:
# np.float64(21.5)

# %%
df.loc[df['cost-effect'] == df['cost-effect'].max(), :]
# Out:
#                                                     country  \
# title
# Bandit NV Merlot (California)                            US
# Cramele Recas 2011 UnWineD Pinot Grigio (Viile ...  Romania
#
#                                                                                           description  \
# title
# Bandit NV Merlot (California)                       There's a lot going on in this Merlot, which i...
# Cramele Recas 2011 UnWineD Pinot Grigio (Viile ...  Notes of sun-dried hay and green flower highli...
#
#                                                    designation  points  price  \
# title
# Bandit NV Merlot (California)                              NaN      86    4.0
# Cramele Recas 2011 UnWineD Pinot Grigio (Viile ...     UnWineD      86    4.0
#
#                                                            province  \
# title
# Bandit NV Merlot (California)                            California
# Cramele Recas 2011 UnWineD Pinot Grigio (Viile ...  Viile Timisului
#
# ...

# %%
# 가성비가 가장 높은 와인 타이틀
list(df.loc[df['cost-effect'] == df['cost-effect'].max(), :].index)
# Out:
# ['Bandit NV Merlot (California)',
#  'Cramele Recas 2011 UnWineD Pinot Grigio (Viile Timisului)']

# %%
# 가성비 가장 높은 와인의 title, 나라, 가격까지 가져오기
df.loc[df['cost-effect'] == df['cost-effect'].max(), ['country', 'price']]
# Out:
#                                                     country  price
# title
# Bandit NV Merlot (California)                            US    4.0
# Cramele Recas 2011 UnWineD Pinot Grigio (Viile ...  Romania    4.0

# %% [markdown]
# - 문제 하나를 해결하기 위해서는 하나의 방법으로 풀수 있는게 아니다. 배운것이 쌓여야만, 큰 문제를 해결할 수 있다.
# - 작은 문제를 많이 풀어야 큰 문제를 풀 수 있다.

# %% [markdown]
# ##  문제3

# %%
# 각 테이스터들은, 각각 몇개의 와인을 테스트 했는지 확인하시오. ( 테스터 이름, 갯수 )

# %%
df.head(2)
# Out:
#                                                 country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                 Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portugal
#
#                                                                                      description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  This is ripe and fruity, a wine that is smooth...
#
#                                                 designation  points  price  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Vulkà Bianco      87    NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)      Avidagos      87   15.0
#
#                                                         province region_1  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Sicily & Sardinia     Etna
# Quinta dos Avidagos 2011 Avidagos Red (Douro)              Douro      NaN
#
# ...

# %%
# 각 테이스터들은, 각각 몇개의 와인을 테스트 했는지 확인하시오. ( 테스터 이름, 갯수 )
df.groupby('taster_name')[ 'winery'].count()
# Out:
# taster_name
# Alexander Peartree      415
# Anna Lee C. Iijima     4415
# Anne Krebiehl MW       3685
# Carrie Dykes            139
# Christina Pickard         6
# Fiona Adams              27
# Jeff Jenssen            491
# Jim Gordon             4177
# Joe Czerwinski         5147
# Kerin O’Keefe         10776
# Lauren Buzzeo          1835
# Matt Kettmann          6332
# Michael Schachner     15134
# Mike DeSimone           514
# Paul Gregutt           9532
# Roger Voss            25514
# Sean P. Sullivan       4966
# Susan Kostrzewa        1085
# Virginie Boone         9537
# Name: winery, dtype: int64

# %%
df.head(2)
# Out:
#                                                 country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                 Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portugal
#
#                                                                                      description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  This is ripe and fruity, a wine that is smooth...
#
#                                                 designation  points  price  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Vulkà Bianco      87    NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)      Avidagos      87   15.0
#
#                                                         province region_1  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Sicily & Sardinia     Etna
# Quinta dos Avidagos 2011 Avidagos Red (Douro)              Douro      NaN
#
# ...

# %% [markdown]
# ## 문제4

# %%
# 사람들이 어떤와인을 더 많이 거론했는지 보려한다. 
# "tropical" 이 들어있는 리뷰의 갯수는? "fruity" 라고 들어있는 리뷰의 갯수는?

# %%
df.head(2)
# Out:
#                                                 country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                 Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portugal
#
#                                                                                      description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  This is ripe and fruity, a wine that is smooth...
#
#                                                 designation  points  price  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Vulkà Bianco      87    NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)      Avidagos      87   15.0
#
#                                                         province region_1  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Sicily & Sardinia     Etna
# Quinta dos Avidagos 2011 Avidagos Red (Douro)              Douro      NaN
#
# ...

# %%
# 활용 : 최근에 가장 많이 나오는 단어들

# %%
# 사람들이 어떤와인을 더 많이 거론했는지 보려한다. 
wine_by_taster = df.groupby(['title'])['taster_name'].nunique().sort_values(ascending=False)
wine_by_taster
# Out:
# title
# Pierre Sparr NV Brut Réserve Sparkling (Crémant d'Alsace)                3
# Torbreck 2006 The Struie Shiraz (Barossa)                                2
# Domaine Charles Baur NV Brut Sparkling (Crémant d'Alsace)                2
# Breathless NV Blanc de Noirs Sparkling (Sonoma County)                   2
# Doyenne 2011 Grand Ciel Vineyard Syrah (Red Mountain)                    2
#                                                                         ..
# Rutherford Ranch 2005 Estate Vineyard Cabernet Sauvignon (Rutherford)    0
# Rutherford Ranch 2005 Cabernet Sauvignon (Napa Valley)                   0
# 10Span 2012 Pinot Gris (Monterey County)                                 0
# 10Span 2012 Chardonnay (Santa Barbara County)                            0
# 10Span 2011 Pinot Noir (Santa Barbara County)                            0
# Name: taster_name, Length: 118840, dtype: int64

# %%
# 사람들이 특성의 와인을 거론했는지 보기
# "tropical" 이 들어있는 리뷰의 갯수는?  '열대의'

# %%
df['description']
# Out:
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                                                                        Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                                                            This is ripe and fruity, a wine that is smooth...
# Rainstorm 2013 Pinot Gris (Willamette Valley)                                                            Tart and snappy, the flavors of lime flesh and...
# St. Julian 2013 Reserve Late Harvest Riesling (Lake Michigan Shore)                                      Pineapple rind, lemon pith and orange blossom ...
# Sweet Cheeks 2012 Vintner's Reserve Wild Child Block Pinot Noir (Willamette Valley)                      Much like the regular bottling from 2012, this...
#                                                                                                                                ...
# ...

# %%
df['description'].str.lower()
# Out:
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                                                                        aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                                                            this is ripe and fruity, a wine that is smooth...
# Rainstorm 2013 Pinot Gris (Willamette Valley)                                                            tart and snappy, the flavors of lime flesh and...
# St. Julian 2013 Reserve Late Harvest Riesling (Lake Michigan Shore)                                      pineapple rind, lemon pith and orange blossom ...
# Sweet Cheeks 2012 Vintner's Reserve Wild Child Block Pinot Noir (Willamette Valley)                      much like the regular bottling from 2012, this...
#                                                                                                                                ...
# ...

# %%
df['description'].str.lower().str.contains("tropical", na=False)
# Out:
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                                                                         True
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                                                            False
# Rainstorm 2013 Pinot Gris (Willamette Valley)                                                            False
# St. Julian 2013 Reserve Late Harvest Riesling (Lake Michigan Shore)                                      False
# Sweet Cheeks 2012 Vintner's Reserve Wild Child Block Pinot Noir (Willamette Valley)                      False
#                                                                                                          ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 Brauneberger Juffer-Sonnenuhr Spätlese Riesling (Mosel)    False
# Citation 2004 Pinot Noir (Oregon)                                                                        False
# ...

# %%
df['description'].str.lower().str.contains("tropical", na=False).sum()
# Out:
# np.int64(3800)

# %%
# "fruity" 라고 들어있는 리뷰의 갯수는?  '과일 같은, 과일 향이 나는'

# %%
df['description'].str.lower()
# Out:
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                                                                        aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                                                            this is ripe and fruity, a wine that is smooth...
# Rainstorm 2013 Pinot Gris (Willamette Valley)                                                            tart and snappy, the flavors of lime flesh and...
# St. Julian 2013 Reserve Late Harvest Riesling (Lake Michigan Shore)                                      pineapple rind, lemon pith and orange blossom ...
# Sweet Cheeks 2012 Vintner's Reserve Wild Child Block Pinot Noir (Willamette Valley)                      much like the regular bottling from 2012, this...
#                                                                                                                                ...
# ...

# %%
df['description'].str.lower().str.contains("fruity", na=False).sum()
# Out:
# np.int64(9455)

# %%
df.head(2)
# Out:
#                                                 country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                 Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portugal
#
#                                                                                      description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  This is ripe and fruity, a wine that is smooth...
#
#                                                 designation  points  price  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Vulkà Bianco      87    NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)      Avidagos      87   15.0
#
#                                                         province region_1  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Sicily & Sardinia     Etna
# Quinta dos Avidagos 2011 Avidagos Red (Douro)              Douro      NaN
#
# ...

# %% [markdown]
# ## 문제5

# %%
# 별점 시스템을 만들려고 한다. 따라서 별점에 대한 데이터가 필요하다. 
# 별점은 1,2,3 즉 3개로 만들것이다. 포인트가 95점 이상이면 3점, 85점 이상이면 2점, 나머지는 1점으로 할 것이다. 
# 리뷰데이터를 통해 각 데이터의 별점을 구하시오.

# %%
# 함수 정의 문제 해결하기
def get_stars(point):

# %%
get_stars(90)
# Out:
# '**'

# %%
df.head(2)
# Out:
#                                                 country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                 Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portugal
#
#                                                                                      description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  This is ripe and fruity, a wine that is smooth...
#
#                                                 designation  points  price  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Vulkà Bianco      87    NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)      Avidagos      87   15.0
#
#                                                         province region_1  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Sicily & Sardinia     Etna
# Quinta dos Avidagos 2011 Avidagos Red (Douro)              Douro      NaN
#
# ...

# %%
# points 컬럼의 점수에 따른 start_point 컬럼 생성하기
df['start_point'] = 
df.head(3)
# Out:
#                                                 country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                 Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)        US
#
#                                                                                      description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  This is ripe and fruity, a wine that is smooth...
# Rainstorm 2013 Pinot Gris (Willamette Valley)  Tart and snappy, the flavors of lime flesh and...
#
#                                                 designation  points  price  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Vulkà Bianco      87    NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)      Avidagos      87   15.0
# Rainstorm 2013 Pinot Gris (Willamette Valley)           NaN      87   14.0
#
# ...
