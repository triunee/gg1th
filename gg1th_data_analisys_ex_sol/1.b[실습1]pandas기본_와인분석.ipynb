# %% [markdown]
# # 와인 데이터 분석

# %%
import pandas as pd
pd.__version__
# Out:
# '3.0.5'

# %% [markdown]
# ## [실습1] 데이터 로딩

# %%
# 데이터에 인덱스 포함되어 있는경우, 인덱스 컬럼 지정
df = pd.read_csv('./datas/winemag-data_first150k.csv', index_col=0)
df.head(2)
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
#
#       region_1 region_2             variety                   winery
# 0  Napa Valley     Napa  Cabernet Sauvignon                    Heitz
# 1         Toro      NaN       Tinta de Toro  Bodega Carmen Rodríguez

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   country      150925 non-null  str
#  1   description  150930 non-null  str
#  2   designation  105195 non-null  str
#  3   points       150930 non-null  int64
#  4   price        137235 non-null  float64
#  5   province     150925 non-null  str
#  6   region_1     125870 non-null  str
#  7   region_2     60953 non-null   str
#  8   variety      150930 non-null  str
#  9   winery       150930 non-null  str
# dtypes: float64(1), int64(1), str(8)
# memory usage: 11.5 MB

# %% [markdown]
# - 주요 컬럼 : country(와인 생산 국가), description(리뷰) points(점수), price(가격), province(지방)

# %%
# 리뷰의 디스크립션 컬럼을 desc로 지정
df.rename({'description':'desc'}, axis=1).head(2)
# Out:
#   country                                               desc  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
#
#       region_1 region_2             variety                   winery
# 0  Napa Valley     Napa  Cabernet Sauvignon                    Heitz
# 1         Toro      NaN       Tinta de Toro  Bodega Carmen Rodríguez

# %% [markdown]
# ## [실습2] 데이터 슬라이싱

# %% [markdown]
# - 디스크립션 컬럼의 첫번째 데이터를, first_description 이라는 변수에 저장하기

# %%
# 방법1
first_description = df['description'].loc[0]
first_description
# Out:
# 'This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak. Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background. Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance. Enjoy 2022–2030.'

# %%
# 방법2
df['description'][0]
# Out:
# 'This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak. Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background. Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance. Enjoy 2022–2030.'

# %%
# 방법3
df.loc[0,'description']
# Out:
# 'This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak. Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background. Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance. Enjoy 2022–2030.'

# %%
# 방법4
df.iloc[0,1]
# Out:
# 'This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak. Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background. Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance. Enjoy 2022–2030.'

# %% [markdown]
# - description column의 값들 중, 첫번재부터 10번째 데이터까지를 first_description 변수에 저장한다.

# %%
first_description = df['description'].loc[:9]
first_description
# Out:
# 0    This tremendous 100% varietal wine hails from ...
# 1    Ripe aromas of fig, blackberry and cassis are ...
# 2    Mac Watson honors the memory of a wine once ma...
# 3    This spent 20 months in 30% new French oak, an...
# 4    This is the top wine from La Bégude, named aft...
# 5    Deep, dense and pure from the opening bell, th...
# 6    Slightly gritty black-fruit aromas include a s...
# 7    Lush cedary black-fruit aromas are luxe and of...
# 8    This re-named vineyard was formerly bottled as...
# 9    The producer sources from two blocks of the vi...
# Name: description, dtype: str

# %%
first_description = df['description'].iloc[:9+1]
first_description
# Out:
# 0    This tremendous 100% varietal wine hails from ...
# 1    Ripe aromas of fig, blackberry and cassis are ...
# 2    Mac Watson honors the memory of a wine once ma...
# 3    This spent 20 months in 30% new French oak, an...
# 4    This is the top wine from La Bégude, named aft...
# 5    Deep, dense and pure from the opening bell, th...
# 6    Slightly gritty black-fruit aromas include a s...
# 7    Lush cedary black-fruit aromas are luxe and of...
# 8    This re-named vineyard was formerly bottled as...
# 9    The producer sources from two blocks of the vi...
# Name: description, dtype: str

# %%
# df.loc[] : 사람용, df.iloc[] : 컴퓨터용
# df.loc[행, 열]
df.loc[:9, 'description']
# Out:
# 0    This tremendous 100% varietal wine hails from ...
# 1    Ripe aromas of fig, blackberry and cassis are ...
# 2    Mac Watson honors the memory of a wine once ma...
# 3    This spent 20 months in 30% new French oak, an...
# 4    This is the top wine from La Bégude, named aft...
# 5    Deep, dense and pure from the opening bell, th...
# 6    Slightly gritty black-fruit aromas include a s...
# 7    Lush cedary black-fruit aromas are luxe and of...
# 8    This re-named vineyard was formerly bottled as...
# 9    The producer sources from two blocks of the vi...
# Name: description, dtype: str

# %% [markdown]
# - 인덱스가 1,2,3,4,5,8 인 데이터를, sample_reviews 변수에 저장한다.

# %%
# sample_reviews = df.iloc[[1,2,3,4,5,8]]
# sample_reviews = df.iloc[[1,2,3,4,5,8], ]
sample_reviews = df.iloc[[1,2,3,4,5,8], :]
sample_reviews
# Out:
#   country                                        description  \
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
# 5   Spain  Deep, dense and pure from the opening bell, th...
# 8      US  This re-named vineyard was formerly bottled as...
#
#                             designation  points  price        province  \
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
# 5                             Numanthia      95   73.0  Northern Spain
# 8                                Silice      95   65.0          Oregon
#
# ...

# %%
# 인덱스가 0, 1, 10, 100인 데이터에서, 컬럼이 country, province, region_1, region_2인 데이터만 가져오기
df.loc[[0, 1, 10, 100], ['country', 'province', 'region_1', 'region_2']]
# Out:
#     country            province     region_1     region_2
# 0        US          California  Napa Valley         Napa
# 1     Spain      Northern Spain         Toro          NaN
# 10    Italy  Northeastern Italy       Collio          NaN
# 100      US          California  South Coast  South Coast

# %% [markdown]
# ## [실습3] 데이터 필터링
# - Italy 에서 만들어진 와인만 가져오기

# %%
# nan 값 포함해서 유니크한 값 가져옴
df['country'].unique()
# Out:
# <StringArray>
# [                    'US',                  'Spain',                 'France',
#                   'Italy',            'New Zealand',               'Bulgaria',
#               'Argentina',              'Australia',               'Portugal',
#                  'Israel',           'South Africa',                 'Greece',
#                   'Chile',                'Morocco',                'Romania',
#                 'Germany',                 'Canada',                'Moldova',
#                 'Hungary',                'Austria',                'Croatia',
#                'Slovenia',                      nan,                  'India',
#                  'Turkey',              'Macedonia',                'Lebanon',
#                  'Serbia',                'Uruguay',            'Switzerland',
#                 'Albania', 'Bosnia and Herzegovina',                 'Brazil',
#                  'Cyprus',              'Lithuania',                  'Japan',
# ...

# %%
df['country'].unique().size
# Out:
# 49

# %%
# unique한 값의 갯수, nan은 제외한 갯수 계산
df['country'].nunique()
# Out:
# 48

# %%
df.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
df['country']=='Italy'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 150925     True
# 150926    False
# 150927     True
# 150928    False
# 150929     True
# Name: country, Length: 150930, dtype: bool

# %%
# - Italy 에서 만들어진 와인만 가져오세요
# df.loc[행,열]
df.loc[df['country']=='Italy', :]
# Out:
#        country                                        description  \
# 10       Italy  Elegance, complexity and structure come togeth...
# 32       Italy  Underbrush, scorched earth, menthol and plum s...
# 35       Italy  Forest floor, tilled soil, mature berry and a ...
# 37       Italy  Aromas of forest floor, violet, red berry and ...
# 38       Italy  This has a charming nose that boasts rose, vio...
# ...        ...                                                ...
# 150920   Italy  Rich and mature aromas of smoke, earth and her...
# 150922   Italy  Made by 30-ish Roberta Borghese high above Man...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                designation  points  price            province  \
# 10      Ronco della Chiesa      95   80.0  Northeastern Italy
# ...

# %%
df.loc[df['country']=='Italy', :]
# Out:
#        country                                        description  \
# 10       Italy  Elegance, complexity and structure come togeth...
# 32       Italy  Underbrush, scorched earth, menthol and plum s...
# 35       Italy  Forest floor, tilled soil, mature berry and a ...
# 37       Italy  Aromas of forest floor, violet, red berry and ...
# 38       Italy  This has a charming nose that boasts rose, vio...
# ...        ...                                                ...
# 150920   Italy  Rich and mature aromas of smoke, earth and her...
# 150922   Italy  Made by 30-ish Roberta Borghese high above Man...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                designation  points  price            province  \
# 10      Ronco della Chiesa      95   80.0  Northeastern Italy
# ...

# %% [markdown]
# - 리뷰점수가 95점 이상이고, Australia 또는 New Zealand 에서 만들어진 와인 데이터를 가져오세요

# %%
(df['points'] >=95)
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 150925    False
# 150926    False
# 150927    False
# 150928    False
# 150929    False
# Name: points, Length: 150930, dtype: bool

# %%
((df['country'] == 'Australia') | (df['country'] == 'New Zealand'))
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 150925    False
# 150926    False
# 150927    False
# 150928    False
# 150929    False
# Name: country, Length: 150930, dtype: bool

# %%
(df['points'] >=95) & ((df['country'] == 'Australia') | (df['country'] == 'New Zealand'))
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 150925    False
# 150926    False
# 150927    False
# 150928    False
# 150929    False
# Length: 150930, dtype: bool

# %%
# 리뷰점수가 95점 이상이고, Australia 또는 New Zealand 에서 만들어진 와인 데이터를 가져오세요
# df.loc[행, 열]
df.loc[(df['points'] >=95) & ((df['country'] == 'Australia') | (df['country'] == 'New Zealand')) , ]
# Out:
#           country                                        description  \
# 2148    Australia  Full-bodied and plush yet vibrant and imbued w...
# 2458    Australia  This is a top example of the classic Australia...
# 3033    Australia  This Cabernet equivalent to Grange has explode...
# 3044    Australia  From vines planted in 1912, this has been an i...
# 3047    Australia  This is a throwback to those brash, flavor-exu...
# ...           ...                                                ...
# 122779  Australia  If Standish's Relic is the feminine side of Sh...
# 127614  Australia  This stellar wine takes a little time in the g...
# 137383  Australia  The 2007 Astralis impresses for its combinatio...
# 150562  Australia  As unevolved as they are, the dense and multil...
# 150563  Australia  Seamless luxury from stem to stern, this ‘baby...
#
#                          designation  points  price         province  \
# ...

# %%
df.loc[(df['points'] >=95) & ((df['country'] == 'Australia') | (df['country'] == 'New Zealand')) , ].shape
# Out:
# (82, 10)

# %% [markdown]
# - 방법2

# %%
(df['points'] >=95) & (df['country'].isin(['Australia', 'New Zealand']))
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 150925    False
# 150926    False
# 150927    False
# 150928    False
# 150929    False
# Length: 150930, dtype: bool

# %%
df.loc[(df['points'] >=95) & (df['country'].isin(['Australia', 'New Zealand'])), ]
# Out:
#           country                                        description  \
# 2148    Australia  Full-bodied and plush yet vibrant and imbued w...
# 2458    Australia  This is a top example of the classic Australia...
# 3033    Australia  This Cabernet equivalent to Grange has explode...
# 3044    Australia  From vines planted in 1912, this has been an i...
# 3047    Australia  This is a throwback to those brash, flavor-exu...
# ...           ...                                                ...
# 122779  Australia  If Standish's Relic is the feminine side of Sh...
# 127614  Australia  This stellar wine takes a little time in the g...
# 137383  Australia  The 2007 Astralis impresses for its combinatio...
# 150562  Australia  As unevolved as they are, the dense and multil...
# 150563  Australia  Seamless luxury from stem to stern, this ‘baby...
#
#                          designation  points  price         province  \
# ...
