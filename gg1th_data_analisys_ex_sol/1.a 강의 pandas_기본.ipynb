# %% [markdown]
# # 데이터 분석 기본 - pandas

# %% [markdown]
# ## Pandas 라이브러리 설치

# %%
# 판다스 설치
# uv add pandas

# %% [markdown]
# ## Pandas 의 장점
# - Allows the use of labels for rows and columns
# - 기본적인 통계데이터 제공
# - NaN values 를 알아서 처리함.
# - 숫자 문자열을 알아서 로드함.
# - 데이터셋들을 merge 할 수 있음.
# - It integrates with NumPy and Matplotlib

# %%
import pandas as pd
pd.__version__
# Out:
# '3.0.5'

# %% [markdown]
# # Pandas Series 이해
# - pandas는 사람 친화적인 데이터분석 라이브러리
# - numpy는 기계 친화적인 데이터분석 라이브러리

# %% [markdown]
# [용어]
# - Series : 판다스의 1차원 데이터를 Series(시리즈) 라고 함.
# - 시리즈의 왼쪽을 인덱스라고 함  => 사람용!!! 임, 데이터가 아님.
# - 시리즈의 오른쪽을 데이터 또는 밸류(values)라고 부름

# %%
index = ['eggs', 'apples', 'milk', 'bread']
data = [30, 6, 'Yes', 'No']

# %%
ser = pd.Series(index=index, data=data)

# %%
ser
# Out:
# eggs       30
# apples      6
# milk      Yes
# bread      No
# dtype: object

# %%
# type 확인
type(ser)
# Out:
# pandas.Series

# %%
# 시리즈 shape 확인
ser.shape
# Out:
# (4,)

# %%
# 시리즈 values 확인
ser.values
# Out:
# array([30, 6, 'Yes', 'No'], dtype=object)

# %%
# 시리즈 index 확인
ser.index
# Out:
# Index(['eggs', 'apples', 'milk', 'bread'], dtype='str')

# %%
# 시리즈 size
ser.size
# Out:
# 4

# %%
# 시리즈의 data type
ser.dtype
# Out:
# dtype('O')

# %%
# 시리즈의 value 카운트하기
ser.value_counts()
# Out:
# 30     1
# 6      1
# Yes    1
# No     1
# Name: count, dtype: int64

# %%
# 시리즈의 차원
ser.ndim
# Out:
# 1

# %% [markdown]
# ## 레이블과 인덱스
# - Accessing and Deleting Elements in Pandas Series

# %%
ser
# Out:
# eggs       30
# apples      6
# milk      Yes
# bread      No
# dtype: object

# %%
ser['eggs']
# Out:
# 30

# %%
# 여러개를 가져올 때는 리스트로
ser[['eggs', 'bread']]
# Out:
# eggs     30
# bread    No
# dtype: object

# %%
# 범위지정
ser['eggs':'milk']
# Out:
# eggs       30
# apples      6
# milk      Yes
# dtype: object

# %% [markdown]
# ## 산술연산자
# - Arithmetic Operations on Pandas Series

# %%
index = ['apples', 'oranges', 'bananas']
data = [10, 6, 3,]

# %%
fruits = pd.Series(data=data, index=index)
fruits
# Out:
# apples     10
# oranges     6
# bananas     3
# dtype: int64

# %%
fruits.values
# Out:
# array([10,  6,  3])

# %%
fruits.index
# Out:
# Index(['apples', 'oranges', 'bananas'], dtype='str')

# %%
fruits
# Out:
# apples     10
# oranges     6
# bananas     3
# dtype: int64

# %%
# 과일을 모두 5개씩 더 들여왔다.
fruits_plus5 = fruits+5
fruits_plus5
# Out:
# apples     15
# oranges    11
# bananas     8
# dtype: int64

# %%
fruits
# Out:
# apples     10
# oranges     6
# bananas     3
# dtype: int64

# %%
# oranges의 갯수가 2개 판배 되었다.
fruits['oranges'] = fruits['oranges']-2
fruits
# Out:
# apples     10
# oranges     4
# bananas     3
# dtype: int64

# %%
# apples 와 bananas가 3개씩 더 들어왔다.
fruits[['apples', 'bananas']] = fruits[['apples', 'bananas']] + 3
fruits
# Out:
# apples     13
# oranges     4
# bananas     6
# dtype: int64

# %% [markdown]
# ## 실습 - 문제 풀이
# import pandas as pd
#
# [] 1. 다음과 같은 레이블과 값을 가지는 Pandas Series 를 만드세요. 변수는 dist_planets 로 만드세요.
# - 각 행성에서 태양까지의 거리(million km)
#     - distance_from_sun = [149.6, 1433.5, 227.9, 108.2, 778.6]
#     - planets = ['Earth','Saturn', 'Mars','Venus', 'Jupiter']
# - dist_planets =
#
# [] 2. 거리를 빛의 상수 c( 18 ) 로 나눠서, 가는 시간이 얼마나 걸리는 지 계산하여 저장하세요.
# - time_light =
#
# [] 3. Boolean indexing을 이용해서 가는 시간이 40분보다 작은것들만 셀렉트 하세요.
# - close_planets =
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1. 다음과 같은 레이블과 값을 가지는 Pandas Series 를 만드세요. 변수는 dist_planets 로 만드세요.

# - distance_from_sun = [149.6, 1433.5, 227.9, 108.2, 778.6]
# - planets = ['Earth','Saturn', 'Mars','Venus', 'Jupiter']
# - dist_planets =

import pandas as pd

distance_from_sun = [149.6, 1433.5, 227.9, 108.2, 778.6]
planets = ['Earth','Saturn', 'Mars','Venus', 'Jupiter']

# 문제 : 시리즈 만들기
dist_planets = 
dist_planets
# Out:
# Earth       149.6
# Saturn     1433.5
# Mars        227.9
# Venus       108.2
# Jupiter     778.6
# dtype: float64

# %%
# 2. 거리를 빛의 상수 c( 18 ) 로 나눠서, 가는 시간이 얼마나 걸리는지 계산하여 저장하세요.
c = 18
time_light = 
time_light
# Out:
# Earth       8.311111
# Saturn     79.638889
# Mars       12.661111
# Venus       6.011111
# Jupiter    43.255556
# dtype: float64

# %%
# 3. Boolean indexing을 이용해서 가는 시간이 40분보다 작은것들만 셀렉트 하세요.
close_planets = 
close_planets
# Out:
# Earth     8.311111
# Mars     12.661111
# Venus     6.011111
# dtype: float64

# %% [markdown]
# # Pandas Dataframe
# - 판다스 2차원 데이터

# %%
# 지금은 실습용으로 딕셔너리로 판다스 2차원 데이터프레임을 만들기만,
# 나중에는 진짜 데이터로 => csv 파일을 읽어서 처리함.

# %% [markdown]
# ### 레이블로 생성하기

# %%
import pandas as pd

# We create a dictionary of Pandas Series
items = {'Bob' : pd.Series(data = [245, 25, 55], index = ['bike', 'pants', 'watch']),
         'Alice' : pd.Series(data = [40, 110, 500, 45], index = ['book', 'glasses', 'bike', 'pants'])}

# %%
df = pd.DataFrame(data=items)
df
# Out:
#            Bob  Alice
# bike     245.0  500.0
# book       NaN   40.0
# glasses    NaN  110.0
# pants     25.0   45.0
# watch     55.0    NaN

# %%
# 판다스에서 2차원 데이터를 처리하는 클래스를 데이터 프레임이라고 한다.
# 데이터 프레임의 왼쪽을 인덱스, 위쪽은 컬럼이라고 부름
# 데이터프레임의 안쪽 부분을 데이터, value라고 함

# %%
df
# Out:
#            Bob  Alice
# bike     245.0  500.0
# book       NaN   40.0
# glasses    NaN  110.0
# pants     25.0   45.0
# watch     55.0    NaN

# %%
df.values
# Out:
# array([[245., 500.],
#        [ nan,  40.],
#        [ nan, 110.],
#        [ 25.,  45.],
#        [ 55.,  nan]])

# %%
df.shape
# Out:
# (5, 2)

# %%
df.index
# Out:
# Index(['bike', 'book', 'glasses', 'pants', 'watch'], dtype='str')

# %%
df.columns
# Out:
# Index(['Bob', 'Alice'], dtype='str')

# %%
df.size
# Out:
# 10

# %%
df.ndim
# Out:
# 2

# %%
df.value_counts()
# Out:
# Bob    Alice
# 245.0  500.0    1
# 25.0   45.0     1
# Name: count, dtype: int64

# %% [markdown]
# ### NaN 은 해당 항목에 값이 없음을 뜻합니다.  (Not a Number)

# %%
# We create a dictionary of Pandas Series without indexes
data = {'Bob' : pd.Series([245, 25, 55]),
        'Alice' : pd.Series([40, 110, 500, 45])}

# %%
df = pd.read_csv('./datas/avocado.csv')
df.head(2)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046      4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74  54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28  44638.81
#
#     4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0  48.16     8696.87     8603.62       93.25          0.0  conventional  2015
# 1  58.33     9505.56     9408.07       97.49          0.0  conventional  2015
#
#    region
# 0  Albany
# 1  Albany

# %% [markdown]
# ### 인덱스 및 컬럼 생성하기

# %%
items = {'Bob' : pd.Series(data = [245, 25, 55], index = ['bike', 'pants', 'watch']),
         'Alice' : pd.Series(data = [40, 110, 500, 45], index = ['book', 'glasses', 'bike', 'pants'])}

# %% [markdown]
# ## Accessing Elements in Pandas DataFrames

# %%
import pandas as pd

# %%
items2 = [{'bikes': 20, 'pants': 30, 'watches': 35},
          {'watches': 10, 'glasses': 50, 'bikes': 15, 'pants':5}]

# %%
# 인덱스를 따로 지정하지 않으며, 파이썬의 기본 인덱스인 0~ 시작하는 숫자로 셋팅됨
# 프랜차이즈 매장 2개를 열었다.
df = pd.DataFrame(data=items2, index=['store1', 'store2'])

# %%
df
# Out:
#         bikes  pants  watches  glasses
# store1     20     30       35      NaN
# store2     15      5       10     50.0

# %%
# 판다스의 데이터에서 데이터를 억세스하는 3가지 방법.
# 1. 컬럼의 값을 가져오는 방법 => 변수명 오른쪽에 대괄호를 쓰고, 컬럼명을 적는다.

# %%
# 팬츠 컬럼의 데이터를 가져오세요.
df['pants']
# Out:
# store1    30
# store2     5
# Name: pants, dtype: int64

# %%
# 팬츠 컬럼의 데이터를 가져오세요.
df.pants
# Out:
# store1    30
# store2     5
# Name: pants, dtype: int64

# %%
# bikes, watches 컬럼 두개 다 가져오기

# %%
df[['bikes', 'watches']]
# Out:
#         bikes  watches
# store1     20       35
# store2     15       10

# %%
# 데이터 프레임에서 데이터 억세스하는 두번째 방법
# 2. 사람용 인덱스와 컬럼명으로 데이터를 가져오는 방법
#  변수명.loc[,]  <= location
#  변수명.iloc[,]

# %%
df
# Out:
#         bikes  pants  watches  glasses
# store1     20     30       35      NaN
# store2     15      5       10     50.0

# %%
# store1의 시계 데이터를 가져오기
df.loc['store1', 'watches']
# Out:
# np.int64(35)

# %%
# store2의 glasses 데이터를 가져오시오.
df
# Out:
#         bikes  pants  watches  glasses
# store1     20     30       35      NaN
# store2     15      5       10     50.0

# %%
df.loc['store2', 'glasses']
# Out:
# np.float64(50.0)

# %%
# store1의 pants watches glasses 데이터를 가져오세요.

# %%
df
# Out:
#         bikes  pants  watches  glasses
# store1     20     30       35      NaN
# store2     15      5       10     50.0

# %%
# df.loc[행의 범위, 열의 범위]
df.loc['store1':'store2', 'pants':'glasses']
# Out:
#         pants  watches  glasses
# store1     30       35      NaN
# store2      5       10     50.0

# %%
# 3번째 방법 : 컴퓨터가 매기는 인데스로 가져오는 방법
#   변수명.iloc[]  <- index location

# %%
df.loc['store1':'store2', ['pants', 'watches', 'glasses']]
# Out:
#         pants  watches  glasses
# store1     30       35      NaN
# store2      5       10     50.0

# %%
df
# Out:
#         bikes  pants  watches  glasses
# store1     20     30       35      NaN
# store2     15      5       10     50.0

# %%
# store0, pants 데이터
# df.iloc[행인덱스,열인덱스]
df.iloc[0 , 1]
# Out:
# np.int64(30)

# %%
# store1의 pants, watches, glasses 데이터 가져오기
df.iloc[0, 1:3+1]
# Out:
# pants      30.0
# watches    35.0
# glasses     NaN
# Name: store1, dtype: float64

# %%
df.iloc[0, 1:]
# Out:
# pants      30.0
# watches    35.0
# glasses     NaN
# Name: store1, dtype: float64

# %%
df.iloc[0, [1, 2, 3]]
# Out:
# pants      30.0
# watches    35.0
# glasses     NaN
# Name: store1, dtype: float64

# %% [markdown]
# - 판다스는 데이터 구조가 2가지
#     - 1차원 시리즈 구조, 2차원 판다스 구조

# %% [markdown]
# ## 데이터에 값 바꾸기

# %% [markdown]
# - 컬럼 데이터 추가

# %%
# store2에 pants 데이터를 20으로 변경

# %%
df
# Out:
#         bikes  pants  watches  glasses
# store1     20     30       35      NaN
# store2     15      5       10     50.0

# %%
# df.loc[index명, '컬럼명']
df.loc['store2', 'pants'] = 20
df
# Out:
#         bikes  pants  watches  glasses
# store1     20     30       35      NaN
# store2     15     20       10     50.0

# %%
# 새로운 컬럼을 만들자. 컬럼명은 shirts라고 만들고, 데이터는 15, 2
df['shirts'] = [15,2]
df
# Out:
#         bikes  pants  watches  glasses  shirts
# store1     20     30       35      NaN      15
# store2     15     20       10     50.0       2

# %%
# suits 컬럼을 만들기. 데이터는 pants의 수와 shirts의 수를 더해서 만든다.
df['pants']
# Out:
# store1    30
# store2    20
# Name: pants, dtype: int64

# %%
df['shirts']
# Out:
# store1    15
# store2     2
# Name: shirts, dtype: int64

# %%
# pants의 갯수 + shirts의 갯수 => suits의 갯수
df['suits'] = df['pants'] + df['shirts']
df
# Out:
#         bikes  pants  watches  glasses  shirts  suits
# store1     20     30       35      NaN      15     45
# store2     15     20       10     50.0       2     22

# %% [markdown]
# # 데이터 프레임 합치기 또는 삭제

# %% [markdown]
# ## 두 데이터 프레임 연결하여 하나로

# %% [markdown]
# - 행추가는 pd.concate() 권장함.

# %%
new_item = [{'bikes': 20, 'pants':30, 'watches': 35, 'glasses': 4}]
new_item
# Out:
# [{'bikes': 20, 'pants': 30, 'watches': 35, 'glasses': 4}]

# %%
new_sotre = pd.DataFrame(data=new_item, index=['store3'])

# %%
#
pd.concat([df, new_sotre], axis=0)
# Out:
#         bikes  pants  watches  glasses  shirts  suits
# store1     20     30       35      NaN    15.0   45.0
# store2     15     20       10     50.0     2.0   22.0
# store3     20     30       35      4.0     NaN    NaN

# %%
df = pd.concat([df, new_sotre], axis=0)
df
# Out:
#         bikes  pants  watches  glasses  shirts  suits
# store1     20     30       35      NaN    15.0   45.0
# store2     15     20       10     50.0     2.0   22.0
# store3     20     30       35      4.0     NaN    NaN

# %% [markdown]
# ## 행삭제, 열삭제
# - 인덱서 삭제, 컬럼 삭제

# %%
df.drop('store3')
# Out:
#         bikes  pants  watches  glasses  shirts  suits
# store1     20     30       35      NaN    15.0   45.0
# store2     15     20       10     50.0     2.0   22.0

# %%
df.drop('store2')
# Out:
#         bikes  pants  watches  glasses  shirts  suits
# store1     20     30       35      NaN    15.0   45.0
# store3     20     30       35      4.0     NaN    NaN

# %%
df.drop('glasses', axis=1)
df
# Out:
#         bikes  pants  watches  glasses  shirts  suits
# store1     20     30       35      NaN    15.0   45.0
# store2     15     20       10     50.0     2.0   22.0
# store3     20     30       35      4.0     NaN    NaN

# %%
df.drop('store3')
# Out:
#         bikes  pants  watches  glasses  shirts  suits
# store1     20     30       35      NaN    15.0   45.0
# store2     15     20       10     50.0     2.0   22.0

# %%
df
# Out:
#         bikes  pants  watches  glasses  shirts  suits
# store1     20     30       35      NaN    15.0   45.0
# store2     15     20       10     50.0     2.0   22.0
# store3     20     30       35      4.0     NaN    NaN

# %%
# 마지막 행만 삭제되는 효과
# df = df.iloc[:-1]
df.iloc[:-1]
# Out:
#         bikes  pants  watches  glasses  shirts  suits
# store1     20     30       35      NaN    15.0   45.0
# store2     15     20       10     50.0     2.0   22.0

# %%
# 마지막 컬럼만 삭제되는 효과
# df = df.iloc[행, 열]
# df = df.iloc[:, :-1]
df.iloc[:, :-1]
# Out:
#         bikes  pants  watches  glasses  shirts
# store1     20     30       35      NaN    15.0
# store2     15     20       10     50.0     2.0
# store3     20     30       35      4.0     NaN

# %%
# bikes, suits 컬럼을 삭제하세요.

# %%
df.drop(['bikes', 'shirts'], axis=1)
# Out:
#         pants  watches  glasses  suits
# store1     30       35      NaN   45.0
# store2     20       10     50.0   22.0
# store3     30       35      4.0    NaN

# %%
df[['pants', 'watches', 'shirts']]
# Out:
#         pants  watches  shirts
# store1     30       35    15.0
# store2     20       10     2.0
# store3     30       35     NaN

# %% [markdown]
# ## 컬럼 이름 변경

# %%
df.rename(index= {'store3':'last store'})
# Out:
#             bikes  pants  watches  glasses  shirts  suits
# store1         20     30       35      NaN    15.0   45.0
# store2         15     20       10     50.0     2.0   22.0
# last store     20     30       35      4.0     NaN    NaN

# %%
df
# Out:
#         bikes  pants  watches  glasses  shirts  suits
# store1     20     30       35      NaN    15.0   45.0
# store2     15     20       10     50.0     2.0   22.0
# store3     20     30       35      4.0     NaN    NaN

# %%
# bites는 hat으로, suits는 shoes로 컬럼명 변경.
df.rename(columns={'bites':'hat', 'suits':'shoes'})
# Out:
#         bikes  pants  watches  glasses  shirts  shoes
# store1     20     30       35      NaN    15.0   45.0
# store2     15     20       10     50.0     2.0   22.0
# store3     20     30       35      4.0     NaN    NaN

# %%
# 인덱스를 통째로 바꾸되, 기존의 컬럼을 인덱스로 만드는 방법

# %%
# 새로운 컬럼 name 컬럼을 만들고, 데이터는 A, B, C로 만듬

# %%
df['name'] = ['A', 'B', 'C']
df
# Out:
#         bikes  pants  watches  glasses  shirts  suits name
# store1     20     30       35      NaN    15.0   45.0    A
# store2     15     20       10     50.0     2.0   22.0    B
# store3     20     30       35      4.0     NaN    NaN    C

# %%
# name 컬럼을 index로 만들고 싶다.
# data가 unique 해야함.
df2 = df.set_index('name')
# df.set_index('name', inplace=True)

# %%
df2
# Out:
#       bikes  pants  watches  glasses  shirts  suits
# name
# A        20     30       35      NaN    15.0   45.0
# B        15     20       10     50.0     2.0   22.0
# C        20     30       35      4.0     NaN    NaN

# %%
# index를 원래 데이터로 변경
df2.reset_index()
# Out:
#   name  bikes  pants  watches  glasses  shirts  suits
# 0    A     20     30       35      NaN    15.0   45.0
# 1    B     15     20       10     50.0     2.0   22.0
# 2    C     20     30       35      4.0     NaN    NaN

# %%
# df에 적용하려면
# df2 = df2.reset_index()
df2.reset_index(inplace=True)
df2
# Out:
#   name  bikes  pants  watches  glasses  shirts  suits
# 0    A     20     30       35      NaN    15.0   45.0
# 1    B     15     20       10     50.0     2.0   22.0
# 2    C     20     30       35      4.0     NaN    NaN

# %% [markdown]
# # Dealing with NaN

# %%
# We create a list of Python dictionaries
items2 = [{'bikes': 20, 'pants': 30, 'watches': 35, 'shirts': 15, 'shoes':8, 'suits':45},
{'watches': 10, 'glasses': 50, 'bikes': 15, 'pants':5, 'shirts': 2, 'shoes':5, 'suits':7},
{'bikes': 20, 'pants': 30, 'watches': 35, 'glasses': 4, 'shoes':10}]

# %%
index_list = ['store1', 'store2', 'store3']

# %%
# 데이터 프레임 생성
df = pd.DataFrame(items2, index= index_list)
df
# Out:
#         bikes  pants  watches  shirts  shoes  suits  glasses
# store1     20     30       35    15.0      8   45.0      NaN
# store2     15      5       10     2.0      5    7.0     50.0
# store3     20     30       35     NaN     10    NaN      4.0

# %%
# 평균을 구하라,
# 학습할 때 nan이 있으면 학습이 되지 않음, 학습하다가 중간에 멈추면 다시 해야함.
# 그러면 GPU를 다시 사용해야하니까 비용 낭비가 됨, 시간 비용

# 함수에서 계수를 찾는것

# %%
# nan이 있는지 파악하는 방법
df.isna()
# Out:
#         bikes  pants  watches  shirts  shoes  suits  glasses
# store1  False  False    False   False  False  False     True
# store2  False  False    False   False  False  False    False
# store3  False  False    False    True  False   True    False

# %%
# 값이 있니?
df.notna()
# Out:
#         bikes  pants  watches  shirts  shoes  suits  glasses
# store1   True   True     True    True   True   True    False
# store2   True   True     True    True   True   True     True
# store3   True   True     True   False   True  False     True

# %%
# 각 컬럼별로 nan의 갯수 세기
df.isna()
# Out:
#         bikes  pants  watches  shirts  shoes  suits  glasses
# store1  False  False    False   False  False  False     True
# store2  False  False    False   False  False  False    False
# store3  False  False    False    True  False   True    False

# %%
# 각 컬럼별로 nan 갯수 세기
# 기본 행 방향으로 더함.
df.isna().sum()
# Out:
# bikes      0
# pants      0
# watches    0
# shirts     1
# shoes      0
# suits      1
# glasses    1
# dtype: int64

# %%
# df 전체에서 nan인 것은 몇개?
df.isna().sum().sum()
# Out:
# np.int64(3)

# %% [markdown]
# ## nan을 처리하는 전략
# - 1. nan이 들어있는 데이터를 삭제함
# - 2. nan에 0을 넣음
# - 3. 각 컬럼의 대푯값으로 채우기(평균, 중앙값, 최빈값)

# %%
# 1. nan이 들어있는 데이터(행)을 삭제함. 전용함수 있음.
df.dropna() # 행삭제
# Out:
#         bikes  pants  watches  shirts  shoes  suits  glasses
# store2     15      5       10     2.0      5    7.0     50.0

# %%
# 2. nan에 모두 0을 넣음
df.fillna(0)
# Out:
#         bikes  pants  watches  shirts  shoes  suits  glasses
# store1     20     30       35    15.0      8   45.0      0.0
# store2     15      5       10     2.0      5    7.0     50.0
# store3     20     30       35     0.0     10    0.0      4.0

# %%
df
# Out:
#         bikes  pants  watches  shirts  shoes  suits  glasses
# store1     20     30       35    15.0      8   45.0      NaN
# store2     15      5       10     2.0      5    7.0     50.0
# store3     20     30       35     NaN     10    NaN      4.0

# %%
# df.fillna(-1)
df.fillna("데이터 없음")
# Out:
#         bikes  pants  watches  shirts  shoes   suits glasses
# store1     20     30       35    15.0      8    45.0  데이터 없음
# store2     15      5       10     2.0      5     7.0    50.0
# store3     20     30       35  데이터 없음     10  데이터 없음     4.0

# %%
# 각 컬럼의 대푯값으로 채우기(평균, 중앙값, 최빈값)
# 각 컬럼의 평균값으로 채우기

# %%
# 각 컬럼별 합계
df.sum()
# Out:
# bikes      55.0
# pants      65.0
# watches    80.0
# shirts     17.0
# shoes      23.0
# suits      52.0
# glasses    54.0
# dtype: float64

# %%
# 각 컬럼별 최소값
df.min()
# Out:
# bikes      15.0
# pants       5.0
# watches    10.0
# shirts      2.0
# shoes       5.0
# suits       7.0
# glasses     4.0
# dtype: float64

# %%
df
# Out:
#         bikes  pants  watches  shirts  shoes  suits  glasses
# store1     20     30       35    15.0      8   45.0      NaN
# store2     15      5       10     2.0      5    7.0     50.0
# store3     20     30       35     NaN     10    NaN      4.0

# %%
df.max()
# Out:
# bikes      20.0
# pants      30.0
# watches    35.0
# shirts     15.0
# shoes      10.0
# suits      45.0
# glasses    50.0
# dtype: float64

# %%
df.mean()
# Out:
# bikes      18.333333
# pants      21.666667
# watches    26.666667
# shirts      8.500000
# shoes       7.666667
# suits      26.000000
# glasses    27.000000
# dtype: float64

# %%
df.median()
# Out:
# bikes      20.0
# pants      30.0
# watches    35.0
# shirts      8.5
# shoes       8.0
# suits      26.0
# glasses    27.0
# dtype: float64

# %%
df
# Out:
#         bikes  pants  watches  shirts  shoes  suits  glasses
# store1     20     30       35    15.0      8   45.0      NaN
# store2     15      5       10     2.0      5    7.0     50.0
# store3     20     30       35     NaN     10    NaN      4.0

# %%
# 각 컬럼의 nan에 각 컬럼의 최소값으로 채우기
df.fillna(df.min())
# Out:
#         bikes  pants  watches  shirts  shoes  suits  glasses
# store1     20     30       35    15.0      8   45.0      4.0
# store2     15      5       10     2.0      5    7.0     50.0
# store3     20     30       35     2.0     10    7.0      4.0

# %%
# 각 컬럼의 nan에 각 컬럼의 평균으로 채우기
df.fillna(df.mean())
# Out:
#         bikes  pants  watches  shirts  shoes  suits  glasses
# store1     20     30       35    15.0      8   45.0     27.0
# store2     15      5       10     2.0      5    7.0     50.0
# store3     20     30       35     8.5     10   26.0      4.0

# %%
df.mode()
# Out:
#    bikes  pants  watches  shirts  shoes  suits  glasses
# 0   20.0   30.0     35.0     2.0      5    7.0      4.0
# 1    NaN    NaN      NaN    15.0      8   45.0     50.0
# 2    NaN    NaN      NaN     NaN     10    NaN      NaN

# %%
# 최빈값
df.fillna(df.mode())
# Out:
#         bikes  pants  watches  shirts  shoes  suits  glasses
# store1     20     30       35    15.0      8   45.0      NaN
# store2     15      5       10     2.0      5    7.0     50.0
# store3     20     30       35     NaN     10    NaN      4.0

# %% [markdown]
# # DataFrame 실습

# %% [markdown]
# - 리스트 데이터 -> series -> df 만들기

# %%
import pandas as pd
import numpy as np

# 각 유저별 별점을 주는것이므로, 1 decimal 로 셋팅.
# pd.set_option('precision', 1)

# 책 제목과 작가, 그리고 유저별 별점 데이터가 있다.

books = pd.Series(data = ['Great Expectations', 'Of Mice and Men', 'Romeo and Juliet', 'The Time Machine', 'Alice in Wonderland' ])
authors = pd.Series(data = ['Charles Dickens', 'John Steinbeck', 'William Shakespeare', ' H. G. Wells', 'Lewis Carroll' ])

user_1 = pd.Series(data = [3.2, np.nan ,2.5])
user_2 = pd.Series(data = [5., 1.3, 4.0, 3.8])
user_3 = pd.Series(data = [2.0, 2.3, np.nan, 4])
user_4 = pd.Series(data = [4, 3.5, 4, 5, 4.2])

#  np.nan values 는 해당 유저가 해당 책에는 아직 별점 주지 않은것이다.
# labels: 'Author', 'Book Title', 'User 1', 'User 2', 'User 3', 'User 4'.
# 아래 그림처럼 나오도록 만든다.

# %%
# 1. 딕셔너리를 만들고,    2. 데이터프레임으로 만든 후,    3. nan을  평균값으로 채운다.

my_data = { 
  'Book Title' : books, 
  'Author' : authors , 
  'User1':user_1, 
  'User2':user_2, 
  'User3': user_3, 
  'User4': user_4  }

# %%
df = pd.DataFrame(data = my_data)
df
# Out:
#             Book Title               Author  User1  User2  User3  User4
# 0   Great Expectations      Charles Dickens    3.2    5.0    2.0    4.0
# 1      Of Mice and Men       John Steinbeck    NaN    1.3    2.3    3.5
# 2     Romeo and Juliet  William Shakespeare    2.5    4.0    NaN    4.0
# 3     The Time Machine          H. G. Wells    NaN    3.8    4.0    5.0
# 4  Alice in Wonderland        Lewis Carroll    NaN    NaN    NaN    4.2

# %%
df.fillna(df.loc['User1':'User4'].mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[325], line 1
# ----> 1 df.fillna(df.loc['User1':'User4'].mean())
#
# File /mnt/e/gg_ai_merbership_1th/data_analisys_ex/.venv/lib/python3.12/site-packages/pandas/util/_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File /mnt/e/gg_ai_merbership_1th/data_analisys_ex/.venv/lib/python3.12/site-packages/pandas/core/frame.py:14475, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   14471         >>> df.mean(numeric_only=True)
#   14472         a   1.5
#   14473         dtype: float64
#   14474         """
# > 14475         result = super().mean(
#   14476             axis=axis, skipna=skipna, numeric_only=numeric_only, **kwargs
#   14477         )
#   14478         if isinstance(result, Series):
#
# File /mnt/e/gg_ai_merbership_1th/data_analisys_ex/.venv/lib/python3.12/site-packages/pandas/core/generic.py:11819, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11815         skipna: bool = True,
#   11816         numeric_only: bool = False,
#   11817         **kwargs,
#   11818     ) -> Series | float:
# > 11819         return self._stat_function(
#   11820             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11821         )
#
# File /mnt/e/gg_ai_merbership_1th/data_analisys_ex/.venv/lib/python3.12/site-packages/pandas/core/generic.py:11773, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11769         nv.validate_func(name, (), kwargs)
#   11770
#   11771         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   11772
# > 11773         return self._reduce(
#   11774             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11775         )
#
# File /mnt/e/gg_ai_merbership_1th/data_analisys_ex/.venv/lib/python3.12/site-packages/pandas/core/frame.py:13635, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   13631             df = df.T
#   13632
#   13633         # After possibly _get_data and transposing, we are now in the
#   13634         #  simple case where we can use BlockManager.reduce
# > 13635         res = df._mgr.reduce(blk_func)
#   13636         out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   13637         out.name = None
#   13638         if out_dtype is not None and out.dtype != "boolean":
#
# File /mnt/e/gg_ai_merbership_1th/data_analisys_ex/.venv/lib/python3.12/site-packages/pandas/core/internals/managers.py:1694, in BlockManager.reduce(self, func)
#    1691 # If 2D, we assume that we're operating column-wise
#    1692 assert self.ndim == 2
# -> 1694 res_blocks = [blk.reduce(func) for blk in self.blocks]
#    1695 index = default_index(1)  # placeholder
#    1696 # shallow copy self.items not needed because DataFrame._reduce does a getitem
#
# File /mnt/e/gg_ai_merbership_1th/data_analisys_ex/.venv/lib/python3.12/site-packages/pandas/core/internals/blocks.py:358, in Block.reduce(self, func)
#     352 @final
#     353 def reduce(self, func) -> Block:
#     354     # We will apply the function and reshape the result into a single-row
#     355     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     356     assert self.ndim == 2
# --> 358     result = func(self.values)
#     360     if self.values.ndim == 1:
#     361         res_values = result
#
# File /mnt/e/gg_ai_merbership_1th/data_analisys_ex/.venv/lib/python3.12/site-packages/pandas/core/frame.py:13563, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   13559         def blk_func(values, axis: Axis = 1):
#   13560             if isinstance(values, ExtensionArray):
#   13561                 if not is_1d_only_ea_dtype(values.dtype):
#   13562                     return values._reduce(name, axis=1, skipna=skipna, **kwds)
# > 13563                 return values._reduce(name, skipna=skipna, keepdims=True, **kwds)
#   13564             else:
#   13565                 return op(values, axis=axis, skipna=skipna, **kwds)
#
# File /mnt/e/gg_ai_merbership_1th/data_analisys_ex/.venv/lib/python3.12/site-packages/pandas/core/arrays/string_.py:968, in StringArray._reduce(self, name, skipna, keepdims, axis, **kwargs)
#     965         return self._from_sequence([result], dtype=self.dtype)
#     966     return result
# --> 968 raise TypeError(f"Cannot perform reduction '{name}' with string dtype")
#
# TypeError: Cannot perform reduction 'mean' with string dtype

# %% [markdown]
# => nan이 있을 경우는 mean 연산 수행 오류가 발생함

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Book Title  5 non-null      str
#  1   Author      5 non-null      str
#  2   User1       2 non-null      float64
#  3   User2       4 non-null      float64
#  4   User3       3 non-null      float64
#  5   User4       5 non-null      float64
# dtypes: float64(4), str(2)
# memory usage: 372.0 bytes

# %%
# 각 컬럼의 평균으로 nan 채우기
# df.mean(numeric_only=True)
df.fillna(df.mean(numeric_only=True))
# Out:
#             Book Title               Author  User1  User2     User3  User4
# 0   Great Expectations      Charles Dickens   3.20  5.000  2.000000    4.0
# 1      Of Mice and Men       John Steinbeck   2.85  1.300  2.300000    3.5
# 2     Romeo and Juliet  William Shakespeare   2.50  4.000  2.766667    4.0
# 3     The Time Machine          H. G. Wells   2.85  3.800  4.000000    5.0
# 4  Alice in Wonderland        Lewis Carroll   2.85  3.525  2.766667    4.2

# %% [markdown]
# ## Loading Data into a Pandas DataFrame

# %%
# csv 파일을 읽어서 처리함
# json/jsonl 파일을 읽어서 처리함

# %%
# 데이터베이스의 테이블 데이터, 엑셀의 데이터 => CSV로 내보내기
# 구글의 주식 데이터 정보
df = pd.read_csv('./datas/GOOG.csv')
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2004-08-19   49.676899   51.693783   47.669952   49.845802   49.845802
# 1     2004-08-20   50.178635   54.187561   49.925285   53.805050   53.805050
# 2     2004-08-23   55.017166   56.373344   54.172661   54.346527   54.346527
# 3     2004-08-24   55.260582   55.439419   51.450363   52.096165   52.096165
# 4     2004-08-25   52.140873   53.651051   51.604362   52.657513   52.657513
# ...          ...         ...         ...         ...         ...         ...
# 3308  2017-10-09  980.000000  985.424988  976.109985  977.000000  977.000000
# 3309  2017-10-10  980.000000  981.570007  966.080017  972.599976  972.599976
# 3310  2017-10-11  973.719971  990.710022  972.250000  989.250000  989.250000
# 3311  2017-10-12  987.450012  994.119995  985.000000  987.830017  987.830017
# 3312  2017-10-13  992.000000  997.210022  989.000000  989.679993  989.679993
#
#         Volume
# 0     44994500
# 1     23005800
# 2     18393200
# 3     15361800
# 4      9257400
# ...        ...
# 3308    891400
# 3309    968400
# 3310   1693300
# 3311   1262400
# 3312   1157700
#
# [3313 rows x 7 columns]

# %% [markdown]
# - 확률통계는 과정에 녹여서 진행한다.

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3313.000000  3313.000000  3313.000000  3313.000000  3313.000000
# mean    380.186092   383.493740   376.519309   380.072458   380.072458
# std     223.818650   224.974534   222.473232   223.853780   223.853780
# min      49.274517    50.541279    47.669952    49.681866    49.681866
# 25%     226.556473   228.394516   224.003082   226.407440   226.407440
# 50%     293.312286   295.433502   289.929291   293.029114   293.029114
# 75%     536.650024   540.000000   532.409973   536.690002   536.690002
# max     992.000000   997.210022   989.000000   989.679993   989.679993
#
#              Volume
# count  3.313000e+03
# mean   8.038476e+06
# std    8.399521e+06
# min    7.900000e+03
# 25%    2.584900e+06
# 50%    5.281300e+06
# 75%    1.065370e+07
# max    8.276810e+07

# %%
# 3.313000e+03
# e+03 : 10의 3승 : 1000
# e-03 : 10dml -3승  : 0.001

# %%
df.head(3)
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2004-08-19  49.676899  51.693783  47.669952  49.845802  49.845802  44994500
# 1  2004-08-20  50.178635  54.187561  49.925285  53.805050  53.805050  23005800
# 2  2004-08-23  55.017166  56.373344  54.172661  54.346527  54.346527  18393200

# %%
df.tail(2)
# Out:
#             Date        Open        High    Low       Close   Adj Close  \
# 3311  2017-10-12  987.450012  994.119995  985.0  987.830017  987.830017
# 3312  2017-10-13  992.000000  997.210022  989.0  989.679993  989.679993
#
#        Volume
# 3311  1262400
# 3312  1157700

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3313 entries, 0 to 3312
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3313 non-null   str
#  1   Open       3313 non-null   float64
#  2   High       3313 non-null   float64
#  3   Low        3313 non-null   float64
#  4   Close      3313 non-null   float64
#  5   Adj Close  3313 non-null   float64
#  6   Volume     3313 non-null   int64
# dtypes: float64(5), int64(1), str(1)
# memory usage: 181.3 KB

# %% [markdown]
# ## [실습1] 와인데이터 분석 실습
# - 1.[실습]pandas_와인데이터분석.ipynb

# %% [markdown]
# # 데이터 프레임 합치기

# %%
df
# Out:
#    Year     Name Department  Age  Salary
# 0  1990    Alice         HR   25   50000
# 1  1990      Bob         RD   30   48000
# 2  1990  Charlie      Admin   45   55000
# 3  1991    Alice         HR   26   52000
# 4  1991      Bob         RD   31   50000
# 5  1991  Charlie      Admin   46   60000
# 6  1992    Alice         HR   27   60000
# 7  1992      Bob         RD   32   52000
# 8  1992  Charlie      Admin   47   62000

# %% [markdown]
# ## concat으로 합치기

# %%
pd.concat([df1, df2, df3], axis=0)
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1, df2, df3], axis=1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %% [markdown]
# ### 문제 해결하기

# %%
# Creating a dataframe from a dictionary
raw_data = {
        'Employee ID': ['1', '2', '3', '4', '5'],
        'first name': ['Diana', 'Cynthia', 'Shep', 'Ryan', 'Allen'],
        'last name': ['Bouchard', 'Ali', 'Rob', 'Mitch', 'Steve']}
columns = ['Employee ID', 'first name', 'last name']

# dataframe 만들기
df_Engineering_dept = 
df_Engineering_dept
# Out:
#   Employee ID first name last name
# 0           1      Diana  Bouchard
# 1           2    Cynthia       Ali
# 2           3       Shep       Rob
# 3           4       Ryan     Mitch
# 4           5      Allen     Steve

# %%
raw_data = {
        'Employee ID': ['6', '7', '8', '9', '10'],
        'first name': ['Bill', 'Dina', 'Sarah', 'Heather', 'Holly'],
        'last name': ['Christian', 'Mo', 'Steve', 'Bob', 'Michelle']}

columns =  ['Employee ID', 'first name', 'last name']

# data 프레임 만들기
df_Finance_dept = 
df_Finance_dept
# Out:
#   Employee ID first name  last name
# 0           6       Bill  Christian
# 1           7       Dina         Mo
# 2           8      Sarah      Steve
# 3           9    Heather        Bob
# 4          10      Holly   Michelle

# %%
# 두 데이터 프레임을 행 방향으로 합치기
df_user = 
df_user
# Out:
#   Employee ID first name  last name
# 0           1      Diana   Bouchard
# 1           2    Cynthia        Ali
# 2           3       Shep        Rob
# 3           4       Ryan      Mitch
# 4           5      Allen      Steve
# 0           6       Bill  Christian
# 1           7       Dina         Mo
# 2           8      Sarah      Steve
# 3           9    Heather        Bob
# 4          10      Holly   Michelle

# %% [markdown]
# ## Merge(병합)으로 합치기
# - 두 데이터 프레임간에 연결할 수 있는 key값이 있어야함.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_user
# Out:
#   Employee ID first name  last name
# 0           1      Diana   Bouchard
# 1           2    Cynthia        Ali
# 2           3       Shep        Rob
# 3           4       Ryan      Mitch
# 4           5      Allen      Steve
# 0           6       Bill  Christian
# 1           7       Dina         Mo
# 2           8      Sarah      Steve
# 3           9    Heather        Bob
# 4          10      Holly   Michelle

# %%
df_Engineering_dept
# Out:
#   Employee ID first name last name
# 0           1      Diana  Bouchard
# 1           2    Cynthia       Ali
# 2           3       Shep       Rob
# 3           4       Ryan     Mitch
# 4           5      Allen     Steve

# %%
raw_data = {
        'Employee ID': ['1', '2', '3', '4', '5', '7', '8', '9', '10'],
        'Salary [$/hour]': [25, 35, 45, 48, 49, 32, 33, 34, 23]}
df_salary = pd.DataFrame(raw_data, columns = ['Employee ID','Salary [$/hour]'])
df_salary
# Out:
#   Employee ID  Salary [$/hour]
# 0           1               25
# 1           2               35
# 2           3               45
# 3           4               48
# 4           5               49
# 5           7               32
# 6           8               33
# 7           9               34
# 8          10               23

# %%
#  inner join
# df_Engineering_dept와 df_salary

# %%
# 데이터 프레임 병합
inner_join = pd.merge(df_Engineering_dept, df_salary, on='Employee ID', how='inner')
inner_join
# Out:
#   Employee ID first name last name  Salary [$/hour]
# 0           1      Diana  Bouchard               25
# 1           2    Cynthia       Ali               35
# 2           3       Shep       Rob               45
# 3           4       Ryan     Mitch               48
# 4           5      Allen     Steve               49

# %%
# 데이터 프레임 병합
inner_join = pd.merge(df_Engineering_dept, df_salary, on='Employee ID', how='left')
inner_join
# Out:
#   Employee ID first name last name  Salary [$/hour]
# 0           1      Diana  Bouchard               25
# 1           2    Cynthia       Ali               35
# 2           3       Shep       Rob               45
# 3           4       Ryan     Mitch               48
# 4           5      Allen     Steve               49

# %%
# 데이터 프레임 병합
inner_join = pd.merge(df_Engineering_dept, df_salary, on='Employee ID', how='right')
inner_join
# Out:
#   Employee ID first name last name  Salary [$/hour]
# 0           1      Diana  Bouchard               25
# 1           2    Cynthia       Ali               35
# 2           3       Shep       Rob               45
# 3           4       Ryan     Mitch               48
# 4           5      Allen     Steve               49
# 5           7        NaN       NaN               32
# 6           8        NaN       NaN               33
# 7           9        NaN       NaN               34
# 8          10        NaN       NaN               23

# %%
# 데이터 프레임 병합
inner_join = pd.merge(df_Engineering_dept, df_salary, on='Employee ID', how='right')
inner_join
# Out:
#   Employee ID first name last name  Salary [$/hour]
# 0           1      Diana  Bouchard               25
# 1           2    Cynthia       Ali               35
# 2           3       Shep       Rob               45
# 3           4       Ryan     Mitch               48
# 4           5      Allen     Steve               49
# 5           7        NaN       NaN               32
# 6           8        NaN       NaN               33
# 7           9        NaN       NaN               34
# 8          10        NaN       NaN               23

# %% [markdown]
# # EXCELLENT JOB!
